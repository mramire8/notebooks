# %% [markdown]
# ## Analysis of Document Scores per Sentence
#
# Experiment:
#
# * Train a learner on 200 documents (bootstrap, balanced?)
#
# * Pick 100 random documents and print for each:
#     * Label
#     * for each sentence print student score ($\max_y P_S(y|s)$) and text

# %%
import sys
import os
sys.path.append(os.path.abspath('C:/cygwin/home/mramire8/python_code/structured'))

# %%
import utilities.experimentutils as exputil
import learner
import utilities.datautils as datautil
import numpy as np
import experiment.base as exp
import nltk

# %%
## Get the data ready
imdb_path = 'C:/Users/mramire8/Documents/Research/Oracle confidence and Interruption/dataset/aclImdb/raw-data'
rnd = np.random.RandomState(2345)
clf = exputil.get_classifier('lrl2',parameter=1)
expert = exputil.get_classifier('lrl2',parameter=1)
vct = exputil.get_vectorizer({'vectorizer':"tfidf", 'limit':None, 'min_size':None})
data = datautil.load_dataset('imdb', imdb_path, categories=None, rnd=5463, shuffle=True)
data.train.bow = vct.fit_transform(data.train.data)
expert = exputil.get_classifier('lrl2',parameter=1)

# %%
## Set the learner options and expert
sent_tk = nltk.data.load('tokenizers/punkt/english.pickle')
st = learner.strategy.StructuredLearner(clf)
st.set_sent_tokenizer(sent_tk)
st.set_vct(vct)
st.set_snippet_utility('sr')
st.set_calibration(True)
expert.fit(data.train.bow, data.train.target)
# Out:
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, penalty='l2', random_state=None, tol=0.0001)

# %%
## Get the boostrap and train
data.train.remaining = rnd.permutation(len(data.train.target))
## balanced bootstrap
# bt_obj = learner.strategy.BootstrapFromEach(None, seed=5463)
# initial = bt_obj.bootstrap(data.train, step=200, shuffle=True)
## random bootstrap 
data.train.data = np.array(data.train.data, dtype=object)
initial = rnd.choice(data.train.remaining, 200, replace=False)
st.fit(data.train.bow[initial], data.train.target[initial], doc_text=data.train.data[initial])

# %%
## Select N random documents
n = 100
rnd_docs = list(set(data.train.remaining) - set(initial))
np.random.shuffle(rnd_docs)
print len(rnd_docs), rnd_docs[:10]
# Out:
# 24800 [18718, 952, 24703, 10471, 11871, 9, 12662, 4055, 14095, 15423]

# %%
# Process
## Get the sentences per document
sent = sent_tk.tokenize_sents(data.train.data[rnd_docs[:n]])

## compute the max scoring snippet (with calibration)
sent_scores, snippet_text = st._compute_snippet(data.train.data[rnd_docs[:n]])

def print_document_senteces(data, st, indices, n=100):
    results = []
    for i, idx in enumerate(indices[:n]):
        doc_i = []
        bow = vct.transform(sent[i])
        pred = st.snippet_model.predict(bow)
        exp_pred = expert.predict(bow)
        for j, s in enumerate(zip(sent[i], pred, exp_pred)):
            selected = False
            if snippet_text[i] == s[0]:
                selected = True
            doc_i.append([i, data.target[idx], j, s[1], s[2],st._snippet_max(bow[j]), s[0], selected])
#         doc_i.extend([sent_scores[i], snippet_text[i]])
        results.extend(doc_i)
    return results

# r =  print_document_senteces(data.train, st, rnd_docs)
# "\n".join(["{}\t".format(str(x)) for x in r])

# #print scores per sentence
## DOCID, TARGET(True label), SENTENCE ID, PRED (student), SCORE(maxprob), Text
d = 0
for i, idx in enumerate(rnd_docs[:n]):
    
    print "-"*40
    print "Doc:", i
    print "Target:", data.train.target[idx]
    
    bow = vct.transform(sent[i])
    pred = st.snippet_model.predict(bow)
    exp_pred = expert.predict(bow)
    print "ID\tPred\tExpertPred\tScore\ttext"
    for j, s in enumerate(zip(sent[i], pred, exp_pred)):
        if snippet_text[i] == s[0]:  # if selected sentence, mark it
            print "*%s\t%s\t%s\t%.3f\t%s" % (j, s[1], s[2], st._snippet_max(bow[j]), s[0])
        else:
            print "%s\t%s\t%s\t%.3f\t%s" % (j, s[1], s[2], st._snippet_max(bow[j]), s[0])
        d +=1
    print sent_scores[i], snippet_text[i]

print d
# Out:
# ----------------------------------------
# Doc: 0
# Target: 1
# ID	Pred	ExpertPred	Score	text
# 0	0	0	0.578	the only word that sums up this movie is quirky.
# 1	0	1	0.560	it's a light-hearted romp through an existential concept.
# 2	1	1	0.525	bouncy (in more way than one) and a bit nutty.
# *3	0	1	0.649	i wouldn't exactly call it grand and unforgettable cinema and it doesn't seem quite as memorable as the director's first movie "cube" but it's a good pit of fluff to watch on a Sunday morning.
# 4	0	0	0.547	the acting veers from respectable to annoying at times but i believe that's how it was to be written.
# 5	0	1	0.629	done as a serious movie it could perhaps have been great or may very well have stepped into a state of pretension.
# 6	0	1	0.543	a little like "the matrix" meets "head" meets "human nature".<br /><br />6.8 out of ten
# 0.656295057453 i wouldn't exactly call it grand and unforgettable cinema and it doesn't seem quite as memorable as the director's first movie "cube" but it's a good pit of fluff to watch on a Sunday morning.
# ----------------------------------------
# Doc: 1
# Target: 1
# ID	Pred	ExpertPred	Score	text
# *0	1	1	0.555	I was so glad I came across this short film.
# 1	1	0	0.503	I'm always so disappointed that short films are hard to come across, so when I saw this and saw that it was nominated for the Live Action Short Film at the Academy Awards, I was so pleased that I actually had a film that I was rooting for.<br /><br />The plot is pretty simple, the director, writer, and star Nacho Vigalondo tried coming up with a reason people would suddenly break out into a song and dance number like they do in movie musicals.
# 2	1	1	0.551	The result is extremely entertaining and the song is actually really catchy.<br /><br />It's a well made short film, well edited and the actors all do a great job.
# 3	1	1	0.507	And the last shot of the film is perfect.<br /><br />I highly recommend this film.
# 0.0267907885001 I was so glad I came across this short film.
# ----------------------------------------
# Doc: 2
# Target: 1
# ID	Pred	ExpertPred	Score	text
# *0	0	0	0.655	The premise is a bit better than the execution, but that doesn't mean the film is worth a look.
# 1	1	1	0.559	Splendid supporting cast makes this a fun mystery to unravel.
# 2	1	1	0.507	Raines is great as the resourceful woman determined to solve this puzzlement.
# 3	0	1	0.517	I always enjoy Thomas Gomez.
# 0.750921096665 The premise is a bit better than the execution, but that doesn't mean the film is worth a look.
# ----------------------------------------
# Doc: 3
# Target: 1
# ID	Pred	ExpertPred	Score	text
# 0	0	1	0.524	Presenting Lily Mars may have provided Judy Garland with one of the easier roles she had while at MGM because Lily Mars is definitely a character she could identify with.
# 1	1	0	0.549	A young girl with talent enough for ten, she knows she has what it takes to make it in the theater no matter how much producer Van Heflin from her home town discourages her.<br /><br />I really liked Judy in this one as the girl determined to make it in the theater.
# 2	0	1	0.505	Because it is Judy Garland with the talent of Judy Garland you in the audience know she has the right stuff even if it takes Van Heflin nearly the whole movie to be convinced.<br /><br />Both Judy and Heflin hail from the same small town, Heflin's dad was the town doctor who delivered her and Heflin while he may have moved away and become a big producer on Broadway, their respective moms, Fay Bainter and Spring Byington have kept in touch.
# 3	0	1	0.543	That's her entrÃ©e, but Heflin's constantly barraged with stagestruck kids, but never anyone quite like Lily Mars.<br /><br />No real big song hits came out of Presenting Lily Mars for Garland, though she sings all her numbers.
# 4	0	1	0.532	The best in the film is a revival of that gaslight era chestnut, Every Little Movement Has A Meaning All Its Own.
# 5	0	1	0.598	Judy sings it with Connie Gilchrist playing the cleaning lady in a Broadway theater where Heflin's show is being produced.
# 6	0	1	0.548	Gilchrist was a star back in the days of the FloraDora Girls and she and Judy deliver the song in grand style with Connie.
# 7	0	1	0.534	It's the best scene in the film as Gilchrist encourages Judy to keep at it.
# 8	0	1	0.541	Composer Karl Hoschna had died a long time ago, but lyricist Otto Harbach was still alive and I'm betting he liked what he heard.<br /><br />European musical star Marta Eggerth is in Presenting Lily Mars as the show's star who's at first bemused, then angry and finally, understanding of Garland and Heflin.
# 9	0	0	0.570	She did a couple of films with MGM and then went back to Europe for more work on the continent.
# 10	1	1	0.548	I'm betting MGM didn't quite know what to do with her and her thick Hungarian accent, though Louis B. Mayer never met a soprano he didn't like.<br /><br />Van Heflin does well as the patient producer who puts up with a lot from Garland and Eggerth.
# *11	0	0	0.659	Heflin was just coming off his Oscar for Johnny Eager the previous year and he and Garland wouldn't appear to be an ideal screen team, but they're not bad together.<br /><br />Presenting Lily Mars is a fine showcase for the talents of Judy Garland.
# 12	1	1	0.547	And she didn't have to share the screen in another backstage film with Mickey Rooney.
# 0.810619576053 Heflin was just coming off his Oscar for Johnny Eager the previous year and he and Garland wouldn't appear to be an ideal screen team, but they're not bad together.<br /><br />Presenting Lily Mars is a fine showcase for the talents of Judy Garland.
# ----------------------------------------
# Doc: 4
# Target: 1
# ID	Pred	ExpertPred	Score	text
# 0	0	0	0.561	The only show I have watched since 90210!
# *1	0	0	0.829	Why did they discontinue it?
# 2	0	1	0.648	It was the only show that captured the essence of Hawaii and made you feel like you are a part of it all!
# 3	0	1	0.564	The least they should do is release it on DVD!
# 4	0	0	0.576	<br /><br />I checked out similar shows, but nothing has come close.
# 5	1	1	0.645	The cast had incredible chemistry and I looked forward to each episode with much anticipation.
# 6	0	0	0.660	<br /><br />They made a big mistake by pulling that show.
# 7	0	0	0.634	If anyone has any info regarding where I can obtain a DVD of North Shore please post a few lines here.
# 8	0	1	0.575	Thanks!
# 9	0	0	0.589	Aloha!
# 3.30881804029 Why did they discontinue it?
# ----------------------------------------
# Doc: 5
# Target: 0
# ID	Pred	ExpertPred	Score	text
# 0	0	0	0.696	The First Power (1990) was a terrible film that came out during the late 80's/ early 90's era of cheaply made horror films.
# 1	0	0	0.500	I found this movie very boring but extremely hilarious in some parts.
# 2	0	0	0.627	This movie lacks so much sense and credibility that it ain't even funny.
# 3	0	0	0.612	The swift justice system in this film makes Texas look weak by comparison.
# 4	1	0	0.545	Lou Diamond Phillips is in way over his head with this role (he plays a hard-boiled cop) and Tracey Griffith (Melanie's more attractive sister) plays a psychic.
# *5	0	0	0.841	Don't waste your time with this one because it's bad.
# 6	0	1	0.727	What a minute, I take it back.
# 7	1	1	0.504	This movie makes a great party film.
# 8	0	0	0.622	Check out the switchblade crucifix packing nun, she has the nicest legs I've ever seen on a Nun that wasn't in a Jesus Franco nunsploitation flick.
# 9	1	0	0.569	Yeow!<br /><br />This marked an end of an era for L.D.P.
# 10	0	0	0.559	His star was tarnished and he couldn't draw flies to a dung heap.
# 11	0	1	0.625	It was D.T.V.
# 12	0	1	0.507	for him until his "ressurection" a few years later.<br /><br />Not recommended unless you're desperate.
# 3.49238498374 Don't waste your time with this one because it's bad.
# ----------------------------------------
# Doc: 6
# Target: 1
# ID	Pred	ExpertPred	Score	text
# *0	0	0	0.683	This movie is just so good!
# 1	0	0	0.631	Despite Carmen Electra, this has to be one of the better films I have seen in awhile.
# 2	1	1	0.596	Jamie Kennedy is just amazing, and Loren Dean plays an insane spoiled movie star very well.
# 3	1	1	0.574	The plot is great as well.
# 4	0	1	0.528	It's all very real which is scary.
# 5	0	1	0.503	It says here that it's a drama, but this is one of the damn funniest dramas I have ever seen.
# 6	0	1	0.519	Go check it out.
# 1.16808854861 This movie is just so good!
# ----------------------------------------
# Doc: 7
# Target: 1
# ID	Pred	ExpertPred	Score	text
# 0	1	1	0.571	One of the most heart-warming foreign films I've ever seen.<br /><br />The young girl is an amazing talent.
# 1	1	1	0.607	Stellar performances by her (Doggie), the old man (the king of masks), and Liang (the Living Boddhisatva).<br /><br />(SPOILER) The deplorable treatment of children, especially females is disturbing.<br /><br />Loved the music.
# *2	1	1	0.686	The original Chinese dialog heightens the emotional intensity of the performances and the story.<br /><br />This is a MUST SEE -- enjoyable family film, although not for very young children.
# 3	0	1	0.540	Would have rated the DVD release even higher if the soundtrack had been transferred better onto the DVD and the transfer had included the widescreen version.
# 2.89436745648 The original Chinese dialog heightens the emotional intensity of the performances and the story.<br /><br />This is a MUST SEE -- enjoyable family film, although not for very young children.
# ----------------------------------------
# Doc: 8
# Target: 0
# ID	Pred	ExpertPred	Score	text
# 0	0	1	0.536	Ok, I first saw this movie like at 9:00 on Cinemax a few weeks ago and thought it would be award winning, boy was I 180d on that.
# 1	1	1	0.548	This movie bit the big one.
# 2	1	0	0.545	I mean, the mother of the monsters shows her true form only at the end of the movie.
# 3	0	1	0.597	I'm going " That's it?
# 4	0	1	0.615	Why doesn't she show it briefly a little bit more earlier in the movie."
# 5	0	0	0.529	The plot being the mother and son feast on the blood of young women.
# 6	0	0	0.608	Wouldn't it be better if they just went on, you know, a killing spree killing like a couple of young women each, then having the sheriff or a cop find out about and get into the old find a way to kill the monsters,save the young woman/women, and have 1 or 2 more people killed in the process?
# 7	0	0	0.614	I think it would be a hell of a lot better that way.
# 8	1	1	0.629	It also sucks because the son is the main character and he gets killed first.
# 9	0	0	0.675	Why not get rid of the mother first?
# *10	1	0	0.643	Plus, how does she have that strength at the end of the movie when she starts killing people?
# 11	0	0	0.559	She said it herself she was too weak.
# 12	0	0	0.565	What the heck was wrong with Stephen this time?
# 13	0	0	0.663	I can never, ever dis the acting on any movie by any actor, after all, they try their best.
# 14	0	0	0.716	If it weren't for good acting, I'd have given this movie a 1/10.
# 15	1	1	0.567	3/10.
# 1.95321598208 Plus, how does she have that strength at the end of the movie when she starts killing people?
# ----------------------------------------
# Doc: 9
# Target: 0
# ID	Pred	ExpertPred	Score	text
# 0	0	1	0.592	The first time I watched Cold Case was after it had run for about a year on Danish television.
# 1	0	1	0.587	At the time it came to the TV it nearly drowned in 4 or 5 other American crime shows aired roughly the same time.<br /><br />I saw it and I was bored to death.
# 2	0	0	0.548	The substandard actors with the self righteous faces and morals were a pain in the behind.
# *3	0	0	0.702	The entire premise that so much money was given a team of investigators to solve murders dating back 10-20-30 or even 60 years seems so unlikely.<br /><br />The time is also a factor as they only have 50-60 min to tell the story which means that they get a break through just in the nick of time to solve the case and bring justice to surviving family members, if they are still alive.
# 4	0	0	0.606	This combined with the "personal" problems and relations of the investigators which there HAS to be time for leaves the show a complete lackluster.<br /><br />I give it a 2-star rating because of the music i the end which is really the only reason for watching it....which you then of course won't do as that is TOO lame a reason for watching this crap.
# 1.44680756896 The entire premise that so much money was given a team of investigators to solve murders dating back 10-20-30 or even 60 years seems so unlikely.<br /><br />The time is also a factor as they only have 50-60 min to tell the story which means that they get a break through just in the nick of time to solve the case and bring justice to surviving family members, if they are still alive.
# ----------------------------------------
# Doc: 10
# Target: 0
# ID	Pred	ExpertPred	Score	text
# 0	0	0	0.530	After Disney's witty live-action George of the Jungle, I had high hopes for this flick.
# 1	0	0	0.561	Major disappointment.
# *2	0	0	0.791	Thread bare plot, bad acting, bad visual effects.
# 3	0	0	0.540	This film relied on lame one-liners, idiotic ( and pointless) product placement, and the lamest most annoying side-kick in that gadget car thing.
# 4	1	1	0.533	I took two young kids to see it and they where bored out of their mind.
# 5	0	0	0.758	The only laugh received from this movie was bad standby of when needing a laugh show a guy getting it in the groin!
# 2.75181780496 Thread bare plot, bad acting, bad visual effects.
# ----------------------------------------
# Doc: 11
# Target: 0
# ID	Pred	ExpertPred	Score	text
# 0	0	0	0.545	This was a cute movie until the ending.
# 1	0	0	0.550	The ending was merely one more despicable effort to emasculate men and empower women at their expense.
# 2	1	1	0.580	The girl refused to listen to reason and logic and used her passive/aggressive nature to control and impose her will on the guy who ultimately yielded his power and control over the relationship to her.
# 3	1	0	0.515	It is not by chance that she was sitting behind the driver's wheel in the car as they drove away at the end after he had to beg her and plead with her to take him back.
# *4	1	1	0.591	This movie is a victory for all women who think they should be in charge of all men and in control of their relationships with them.
# 5	0	0	0.634	It was a despicable movie for that reason.
# 0.809464829184 This movie is a victory for all women who think they should be in charge of all men and in control of their relationships with them.
# ----------------------------------------
# Doc: 12
# Target: 1
# ID	Pred	ExpertPred	Score	text
# 0	1	1	0.562	I haven't liked many TV shows post 1990, but THAT 70S SHOW is great.
# 1	0	0	0.591	Never seeing it during it's first run, thinking a gimmicky period piece, I was wrong!
# 2	1	1	0.604	I started watching in reruns and the more I watched, the more I liked!
# 3	0	1	0.518	Now, it is the only show premiering post-1990 that I watch regularly.<br /><br />Although THAT 70S SHOW mimics some of the styles, attitudes, music, and tastes of the 70s, it does not mire itself in that decade by going overboard with the references and look of the 70s.
# 4	0	0	0.616	It contains so much funny, witty, biting dialogue that is delivered with confidence and certainty by its main cast that it overcomes any 70s clichÃ©s by just being humorous.
# 5	0	1	0.590	The humor is what keeps the show eternally watchable.<br /><br />Although a hilarious sitcom, no matter what time period, the uniqueness of mocking the 70s does work in its favor as it gives the show a signature identity.
# 6	0	1	0.555	But its the focus on universal issues (family problems, teen angst, marital issues, peer pressure), dealing with all of them with comic aplomb, that gives the show a mass appeal.<br /><br />The show's center is one Eric Forman (played to absolute comic perfection by future superstar Topher Grace).
# 7	0	1	0.616	Eric is a super-skinny, geeky-looking, non-athletic teen and still comes off as super-cool due to Grace's brilliant self-deprecation of the character.
# 8	0	1	0.585	Eric has 5 friends Donna, Hyde, Kelso, Jackie, and Fez (played respectively in hilarious fashion by Laura Prepon, Danny Masterson, Ashton Kutcher, Mila Kunis, and Wilmer Valderama).
# 9	0	1	0.603	We get to see life in Point Place, Wisconsin through the eyes of these 6 teens and boy do we get a lot to see!
# 10	0	1	0.512	Donna, a forward-thinking feminist, is the object of Eric's affection and these 2 have the core relationship of the show.
# 11	0	0	0.616	They become a couple pretty soon after the show starts and they are NEVER a boring couple.
# 12	1	1	0.569	Most of the shows eps end with them having a meaningful conversation about them and their future and it works as a great insightful bookend, which works as a perfect counter to the prior hilarity.
# 13	1	1	0.524	Hyde is Eric's best friend and soon moves in with the Formans when his mother abandons him; Hyde is the mellow, zen, cool one of the group and just sits back, observes, and makes fun of his fellow friends with easygoing aplomb.
# 14	1	1	0.518	Kelso is the dumb one of the group and Kutcher plays it the absolute hilt, displaying amazing physical comedy as well as telling some of the most absurdly hilarious ideas and stories ever!
# 15	0	1	0.595	Jackie, who starts out as Kelso's girlfriend, is a verbose, self-absorbed debutante cheerleader and is at first only accepted as part of the group b/c of Kelso, but she manages to ingratiate herself to the point where they all HAVE to accept her!
# 16	0	1	0.513	And finally, Fez!
# 17	1	1	0.501	Fez is the foreign exchange student from some unknown country (we never know exactly where) and he is a scene-stealer!
# 18	0	1	0.612	"I said good day!"
# 19	0	1	0.556	"You son of a b*tch!"
# 20	1	1	0.562	Valderama is only sporting a foreign accent here as he hasn't one in reality and he is always in character and creates one of the most unique characters I have ever seen.
# 21	0	0	0.553	His scene-stealing moments often help make the show for me.<br /><br />The show constantly takes us into the minds and thoughts of these characters through engaging fantasy scenes of how they would like or imagine things to be.
# 22	0	0	0.516	The gang repeatedly gets into trouble (most of it on purpose).
# *23	0	1	0.685	They constantly play gags on the Point Place residents as well as each other.
# 24	0	1	0.583	They hang out most of the time in Eric's basement plotting, pontificating, or just plain playing around.<br /><br />Also figuring prominently in the show are Eric's parents, the menacing, commie-hating Red and the lovable, happy-go-lucky Kitty (played memorably by Kurtwood Smith and Debra Jo Rupp).
# 25	0	1	0.595	These 2 adults give the show a much-needed mature point-of-view and constantly berate and advise the 6 ne'er do-wells.
# 26	0	1	0.548	Red and Kitty are ably supported by Donna's parents, the buffoonish Bob (played wonderfully for the full run by Don Stark) and blonde bimbo daft Midge (the super-sexy Tanya Roberts, who was on the show for about half it's run).
# 27	1	1	0.533	Additionally, for 3 full seasons, Eric's sister from hell Laurie (played brilliantly by the wickedly sexy Farrah-Fawcett lookalike Lisa Robin Kelly) was a major refreshing relief to counter the shenanigans of the main 6 and to be the thorn in Eric and her parents' sides!
# 28	0	1	0.505	Kelly came back as a guest character for a few Season 5 eps.
# 29	0	0	0.586	But, unfortunately, Kelly's personal problems led to her being replaced by a terrible new actress in Season 6.
# 30	0	1	0.520	The newbie didn't last, thankfully, and was gone after a few Season 6 eps!<br /><br />Sadly, at the end of Season 7, Topher Grace (Eric) and early in Season 8, Ashton Kutcher (Kelso) left the show and it never recovered as Season 8 turned out to be it's last.
# 31	1	1	0.547	Grace and Kutcher returned for the series finale, though, giving the show a satisfying end.
# 32	1	1	0.595	<br /><br />A lot of great supporting and cameo characters would help keep the show fresh through added nostalgia and humor.
# 33	0	1	0.588	Top notch supporting players were eternally high Leo (played to the hilt by Tommy Chong), Pastor Dave, Roy (the terrific comic Jim Gaffigan), Big Rhonda, Mitch, Earl, etc.
# 34	0	1	0.537	They also got legends Marion Ross (HAPPY DAYS) and Betty White (THE MARY TYLER MOORE SHOW) to play Red and Kitty's mothers, respectively.
# 35	0	1	0.578	Many celebrity cameos from the 70s made appearances as well, from Shirley Jones (PARTRIDGE FAMILY) to Pamela Sue Martin (NANCY DREW) to Charo to Ted Nugent to K.I.S.S!
# 36	0	1	0.556	It goes on and on!<br /><br />With great nostalgic 70s homages and references, hilarious dialogue and delivery and a nonsensical, take-no-prisoners style of comedic storytelling, THAT 70S SHOW is a television classic!
# 1.1953570728 They constantly play gags on the Point Place residents as well as each other.
# ----------------------------------------
# Doc: 13
# Target: 0
# ID	Pred	ExpertPred	Score	text
# 0	0	1	0.551	Horror fans (I'm speaking to the over 12's, although if you're under 12 I apologise for what you might deem an insult): In short, if you appreciate having your imagination disturbed by well written, original storytelling, punctuated by unpredictable well planted scares, and delivered via convincing performances, then I can heartily recommend - AVOIDING THESE STEAMERS - made by directors who have apparently long since past their sell by date.
# 1	0	0	0.677	It's no accident that almost every episode feels as if it were made in the 1980's.
# 2	0	0	0.616	Not to put blame squarely on the shoulders of some of these old boys (or indeed the 80's) because where would we be without certain movies from the likes of Argento, Carpenter, Landis, Dante and Barker (Actually Clive, WTF are you doing in there?!
# 3	0	1	0.615	Glad to see Romero had the good sense to give it a miss as I'm sure he was asked to partake...).
# 4	0	1	0.520	More perhaps we should point the finger at creator Mick Garris whose credentials include the logic defying and depressingly ill-advised TV remake of Stanley Kubrick's masterpiece 'The Shining'.<br /><br />Perhaps it is an indication of the state of television today.
# 5	0	0	0.655	Are we so starved of good TV horror that we applaud any old sloppy schlock that the networks excrete onto our sets?
# 6	0	0	0.703	Sadly, maybe so.<br /><br />Normally I wouldn't see the point of adding a comment that doesn't argue the faults and merits of a production, I'd just rate it accordingly.
# 7	0	0	0.621	However, as this series is woefully lacking in any merit (with perhaps the sole exception of the theme tune) I write this as more of a warning than a review: DON'T WASTE YOUR TIME AND MONEY.
# 8	0	1	0.708	If you disagree with me then it's more than likely that you haven't seen enough decent horror.
# *9	0	0	0.709	Perhaps the earlier films of some of these directors would be a much better place to start, but if these 'Masters' of Horror were being assessed on these works alone, they'd never have been allowed to graduate with even their Bachelor's degree.
# 10	0	0	0.540	Unless of course they were studying for a degree from the University Of S**t.
# 1.54535338206 Perhaps the earlier films of some of these directors would be a much better place to start, but if these 'Masters' of Horror were being assessed on these works alone, they'd never have been allowed to graduate with even their Bachelor's degree.
# ----------------------------------------
# Doc: 14
# Target: 1
# ID	Pred	ExpertPred	Score	text
# 0	1	1	0.549	MacArthur is a great movie with a great story about a great manÂGeneral Douglas MacArthur.
# 1	1	1	0.565	This is of course, the story of one of America's great military figures, and a figure made familiar to me from the earliest moments of my memory.
# 2	0	1	0.606	Though there is a continuity issue (there may be others) e.g.
# 3	0	0	0.627	MacArthur's speech portrayed in the film as his 1962 address to the U.S. Military Academy on accepting the Thayer award did not contain the phrase "old soldiers never die; they just fade away."
# 4	0	1	0.606	(That was in his speech to Congress upon his dismissal by President Truman) in 1951 for his alleged insubordination (these two did not see eye to eye!)
# 5	0	1	0.609	Gregory Peck is im-Peck-able as the general who vowed he would return to the Philippines in World War II.
# 6	1	1	0.580	The film moves quickly and easily with the General, his family and his staff from the beginning of the Second World War to the end of his service career.
# 7	0	1	0.517	This film would be of much greater significance to one familiar with both WW II and the Korean War.
# 8	0	1	0.521	Nevertheless, Peck's portrayal of this great man who fought the twin evils of fascism and communism and who hated war as only a soldier can is a memorable one indeed.
# *9	0	0	0.689	"In war there is no substitute for victory."
# 1.2511216339 "In war there is no substitute for victory."
# ----------------------------------------
# Doc: 15
# Target: 1
# ID	Pred	ExpertPred	Score	text
# 0	0	0	0.622	Okay, there are a ton of reviews here, what can I possibly add?<br /><br />I will try anyway.
# 1	1	1	0.535	<br /><br />The reason this is my favorite Scrooge is because of EVERYthing.
# 2	0	1	0.539	The sets, outdoor locations, costumes are so beautiful and authentic.
# 3	0	1	0.584	The music is sweet.
# 4	1	1	0.593	The supporting cast is very well done.
# 5	0	1	0.543	One of my favorites is the narrator & nephew, played by Roger Rees.
# 6	1	1	0.587	His understated sincerity is touching and his voice is the sound of Christmas to me.
# 7	1	1	0.545	David Warner is also a totally believable Bob Cratchit.
# 8	1	1	0.550	His is a difficult life, but he remains positive and dignified.
# 9	0	1	0.513	<br /><br />The best part of course- is George C. Scott as Ebenezer Scrooge.
# 10	0	0	0.601	Some have said his portrayal too gruff.
# 11	0	0	0.585	I couldn't disagree more.
# 12	0	1	0.577	His exchanges at the beginning while cold or harsh, weren't out of character.
# 13	0	1	0.541	He is a terribly disillusioned man who's heart has been hardened by the vicissitudes of life and his own lust for wealth.
# 14	0	0	0.522	<br /><br />During the flashbacks, it's obvious that he isn't all gruff.
# 15	0	1	0.530	This is where we see that there is hope for him.
# 16	0	0	0.550	If he was totally gone, his partner Marley would never have come for his sake in the first place.
# 17	0	0	0.658	And after all, we are none of us past hoping.
# *18	0	0	0.683	I think that is a HUGE part of what Dickens was trying to say.
# 19	0	1	0.516	When Scrooge looks in on his dance at his employer's with Belle, you see him smile regretfully as he tells Belle in the flashback that he will go through life "with a grin on my face."
# 20	0	0	0.618	Clive Donner was smart enough as the director to allow these moments on film.
# 21	0	1	0.514	Sometimes they get left on the editing room floor.<br /><br />And finally, his conversion is so absolutely full of joy that it makes me cry tears of joy EVERY time I see it.
# 22	0	0	0.573	His apology to his nephew Fred, so sincere, so moving, it is the spirit not only of Christmas, but of humanity itself.
# 23	1	1	0.546	The joy he brings to Fred, to his wife are so apparent.
# 24	1	0	0.517	And the line that gets me every time, "God forgive me for the time I've wasted."
# 25	0	0	0.508	<br /><br />Bravi tutti!
# 1.15928568578 I think that is a HUGE part of what Dickens was trying to say.
# ----------------------------------------
# Doc: 16
# Target: 1
# ID	Pred	ExpertPred	Score	text
# 0	0	1	0.582	Reed Hadley makes a better foppish Don Diego than he does a dashing and daring Zorro, but that's almost beside the point because this serial features the bar-none best theme song of any serial, ever -- and the best version of Yakima Canutt's famous stagecoach stunt.
# 1	0	1	0.612	There are other good stunts, and lots of action, and plenty of hair-raising cliff-hanger chapter endings, but if for no other reason, you must see this film to watch the stagecoach stunt, then re-watch it in slow motion.
# *2	0	1	0.635	It is incredible, and, despite the lower budget for this chapter play, Yak turns in a better take on the stunt here than he did in the far more celebrated film "Stagecoach."
# 3	0	1	0.587	Indiana Jones, eat your heart out: This is the real deal!
# 0.458748850775 It is incredible, and, despite the lower budget for this chapter play, Yak turns in a better take on the stunt here than he did in the far more celebrated film "Stagecoach."
# ----------------------------------------
# Doc: 17
# Target: 0
# ID	Pred	ExpertPred	Score	text
# *0	0	0	0.711	Please, help the economy - spend your money elsewhere!
# 1	1	0	0.548	The synopsis of the movie is: the First Lady has her husband assassinated because he was cheating on her.
# 2	0	1	0.612	That's it.
# 3	0	0	0.508	Undetected by anyone, except Cuba and Angie, she designs and implements a vast assassination conspiracy which no one knows about...and gets away completely free.<br /><br />Some specific points are particularly hilarious: While standing in front of the president, Cuba a deflects the assassin's bullet...which then enters the back of the president's head.<br /><br />Cuba and Angie watch film from a news camera, and they see...a clue.
# 4	0	1	0.517	They go to great lengths to protect the film, believing that they are the only people that have a copy of this very public film.<br /><br />Cuba speaks with a presidential staff member.
# 5	0	0	0.697	The PSM comments that there was no conspiracy.
# 6	0	0	0.565	Cuba claims there was more than one person involved.
# 7	0	0	0.575	The PSM then rants that the conspiracy includes the FBI, the CIA, and the NSA.
# 8	0	0	0.503	Gosh, I wonder is the PSM is involved.<br /><br />Ms Archer, the First Lady, is a craptacular artist.
# 9	0	1	0.547	Cuba can't make out a painting, and she says, "You're too close...stand back...look from a different perspective, look from my perspective."
# 10	0	1	0.631	Can anyone miss THAT clue?
# 1.56897863291 Please, help the economy - spend your money elsewhere!
# ----------------------------------------
# Doc: 18
# Target: 0
# ID	Pred	ExpertPred	Score	text
# 0	0	0	0.614	Gwoemul (The Host) - Due to pollution in the Han river a mutated beast goes on the rampage.
# 1	1	1	0.551	The youngest member of the Park family is snatched by the beast, and it is up to the rest of her family to find her, before she becomes the beast's latest meal.<br /><br />Firstly, I love monster movies: Mutated bears, over-sized alligators, packs of ravening Komodo dragons, the whole lot.
# 2	0	1	0.560	Creature features are my favourite kind of Horror film.
# 3	0	0	0.666	So, I really wanted to like The Host, but it wasn't to be.
# 4	0	1	0.588	<br /><br />There were three major problems with it:<br /><br />The first can be seen with a quick look at it's IMDb page<br /><br />Genre: Action / Comedy / Drama / Fantasy / Horror / Sci-Fi / Thriller<br /><br />Too many damned genres.
# 5	0	0	0.641	It took itself too seriously to be a comedy, and yet was too light hearted to have any real message (though it did seem to be trying to make some kind of statement.
# 6	0	0	0.603	Anti-pollution, anti-American or anti-government).
# 7	0	0	0.659	The drama was misplaced and mixed in a confusing mish-mash with all the other styles.<br /><br />Secondly, after the initial monster attack nothing happens for almost the entire film.
# 8	0	0	0.620	The central family wander about looking for one of their own while the governments of Korea and America, apparently, do nothing.
# 9	0	0	0.626	And that's it, they just wander about, occasionally hitting one another, presumably for a bit of comedy relief.
# 10	1	0	0.506	This lack of action made my attention wander, and apparently it did the same for the director, as whole plot threads go unresolved (a mystery plague invented by the evil Americans is completely forgotten about, and is never resolved).<br /><br />And lastly, the film is clumsily political.
# 11	0	0	0.655	It paints the Americans as being stupid and evil, but gives us no American characters with any more depth than a cartoon villain.
# 12	0	0	0.573	The opening scene has the most obvious stupid American vs wise Korean moment.
# 13	0	0	0.601	With a Korean morgue assistant asking his boss, the coroner, not to pour chemicals into the Han river.
# 14	0	1	0.612	The American coroner all but cackles maniacally as he orders the assistant to carry on.
# 15	0	0	0.583	As well as being racist, it's lazy film-making and there is no excuse for that.<br /><br />On the plus side, the monster is good, kind of a mix of The Relic and Deep Rising.
# 16	1	1	0.565	Some of the movement effects are quite cool, and the initial monster chase through the park is a lot of fun.
# 17	0	1	0.672	There are also some nice shots in the film.
# 18	1	1	0.505	Some of which remind me, strangely, of the way Firefly was filmed (shuddering cameras, out of focus shots etc).There is also a nice scene at the end, where the hero and a little boy he has saved are sitting in the family's mobile food stall.
# 19	0	1	0.565	It's night-time and snow is falling, the street-lamp is giving out a cold light, but the food stall has a warm glow coming from it.<br /><br />Overall, I was really disappointed by this film.
# 20	0	0	0.614	I'd been looking forward to a decent creature flick, and instead I get some pseudo-political,horror-comedy lite.
# 21	0	0	0.753	Looking at the comments on IMDb I can't help but think that if this had been a US production it would have been slated.
# *22	0	0	0.799	Just 'cause it's a foreign flick doesn't mean it's any good.
# 23	0	1	0.568	There have been some great movies out of Korea in recent years (The vengeance trilogy and Brotherhood, for example), but this certainly isn't one of them.
# 24	0	0	0.654	<br /><br />For once I'm in favour of a remake.
# 25	0	0	0.644	Tighten up the directing, improve the scripting and this could have been a nice film.
# 26	1	1	0.507	As it is, it's not worth a couple of hours of anyone's time.
# 2.87306012047 Just 'cause it's a foreign flick doesn't mean it's any good.
# ----------------------------------------
# Doc: 19
# Target: 1
# ID	Pred	ExpertPred	Score	text
# 0	0	1	0.558	Another fun, witty, frothy RKO musical with Astaire and Rogers, FOLLOW THE FLEET is a charming film.
# *1	1	1	0.549	While it lacks the stand-out great tunes of SWNG TIME (although the final number "Face the music and dance" is one of the team's best and rightfully so), it is hugely enjoyable, as these two could virtually do no wrong together in the 1930's.
# 2	0	0	0.584	Once again, the plot is lightweight and forgettable, but watching Fred and Ginger dance together is sheer heaven.
# 3	0	1	0.530	These two conveyed more romance and magic in dance than many couples in films do in a huge love scene.
# 4	0	1	0.528	While there are better Fred and Ginger musicals, this is certainly a must-see.
# -0.105474154192 While it lacks the stand-out great tunes of SWNG TIME (although the final number "Face the music and dance" is one of the team's best and rightfully so), it is hugely enjoyable, as these two could virtually do no wrong together in the 1930's.
# ----------------------------------------
# Doc: 20
# Target: 1
# ID	Pred	ExpertPred	Score	text
# 0	0	1	0.645	YETI deserves the 8 star rating because it is the one of the greatest bad movies ever made.
# 1	1	1	0.590	I saw it at a midnight screening in L.A. and people were roaring and cheering at the insanity - this movie is one of those cinematic trainwrecks where you think it cant get any stranger and THEN IT DOES!
# 2	0	0	0.615	The millionaire who funds the project to thaw the Yeti looks like Chris Penn and John Goodman both poured into an ill-fitting suit - the guy playing the scientist is one of the worst actors to ever appear on screen - and yes, there is a mute boy (who sorta kinda looks like a girl) and he's mute ever since he survived a plane crash that killed both his parents (hmmm- maybe therapy for the kid??).
# 3	1	1	0.501	Then this hottie Italian girl is seen by Yeti (once he thaws - which takes FOREVER) -- and he is instantly in love with her - what is one of the most hysterical things about the movie is that this giant Yeti makes "bedroom eyes" at her - it's like a large Barry White trying to seduce a groupie.
# 4	1	1	0.514	In fact, once the large Yeti picks up the hottie and has her against his chest - she accidentally touches the Yeti's nipple and yes, the film takes the time to show his large grey nipple GET HARD!!!!
# 5	0	0	0.585	Yikes of all YIKES!
# 6	0	1	0.528	Plus there's a collie dog in it because the Italian producer must have heard that American audiences like dogs and he sorta kinda tried to get a Lassie - there's also this insane scene where the Yeti eats a giant fish - keeps the large fishbone and uses it to comb the Italian girl's hair "Gee, thanks Yeti - now my hair is smooth and smells like dead trout.
# *7	1	1	0.661	You're the best."
# 8	0	0	0.607	This film is more bizarre than something Ed Wood could have ever dreamt up.
# 9	1	0	0.534	If you are a fan of classic cinema crap - seek this baby out.
# 2.35236866488 You're the best."
# ----------------------------------------
# Doc: 21
# Target: 1
# ID	Pred	ExpertPred	Score	text
# *0	0	0	0.623	Poor Ivy: Though to the manner born, she had the bad luck to marry a charming wastrel (Richard Ney).
# 1	0	0	0.526	As the movie is set in the 20s or 30s, when rigid Victorian ideas of class were starting to fray at the edges, this uncertain status vexes her unduly.
# 2	0	0	0.584	The Gretorexes (for so they are called) don't know where their next shilling is coming from but there are yachting parties and fancy-dress balls in posh pleasaunces aplenty to tempt her.
# 3	0	1	0.557	When Ivy (Joan Fontaine) makes the acquaintance of a wealthy older gent (Herbert Marshall, who must have been born middle-aged), she sets one of her extravant chapeaux for him.
# 4	1	1	0.557	Luckily, one of the beaux she still strings along (Patric Knowles) is a physician whose consulting rooms provide a cache of poison, with which she bids her hubby farewell.
# 5	0	0	0.562	The fact that it implicates Knowles doesn't phase her a bit, even as the hours trickle by until he should be hanged by the neck until dead.
# 6	0	1	0.612	The turning of the plot depends on police inspector Sir Cedric Hardwicke; Knowles' mother (the redoubtable Lucile Watson); and Knowles' loyal housekeeper (Una O'Connor).
# 7	0	1	0.562	Sam Wood adds some subtle touches to this well above average melodrama; Fontaine's luminous face supplies the rest.
# 0.269105585017 Poor Ivy: Though to the manner born, she had the bad luck to marry a charming wastrel (Richard Ney).
# ----------------------------------------
# Doc: 22
# Target: 0
# ID	Pred	ExpertPred	Score	text
# 0	0	0	0.576	A difficult film to categorize.
# 1	0	0	0.619	I was never giving it 110% concentration & consequently as simple as the plot appeared I couldn't say for certain exactly who was doing what amongst the American FBI characters & what their roles were.
# 2	0	0	0.593	Nor could I take the Irwins seriously as film characters when their lines & scenes were all in the style of one of his shows, not acted out.<br /><br />This is nothing more than a glorified episode of a Discovery TV show, with a largely insignificant sub plot going on, which just seemed to get in the way.
# 3	0	1	0.529	However as any Irwin show is always worth a watch, this film is well worth a look too, but not on Christmas Day.
# *4	0	0	0.643	Talking of which, I've better things to do too than be on here.<br /><br />A high 4/10
# 0.571263063122 Talking of which, I've better things to do too than be on here.<br /><br />A high 4/10
# ----------------------------------------
# Doc: 23
# Target: 0
# ID	Pred	ExpertPred	Score	text
# 0	0	0	0.653	For those deciding whether or not to watch this movie and are reading these comments for insight, I first offer these four words: Don't waste your time!
# 1	0	0	0.624	"Chungking Express" was shoddily filmed, slapped together quickly and seems as though it were conceived in its entirety by someone standing in line at a Hong Kong Burger King.
# 2	0	0	0.695	I can't remember ever watching a film with an assortment of such one-dimensional characters trying to work their way through a script this mundane!
# 3	0	0	0.556	It's an absurd effort with philosophically ridiculous dialog (a man wanders into his flooded apartment and offers the stunning revelation that "tears can be dried with a tissue, but water takes time to mop up").
# 4	0	1	0.531	The same character is also seen carrying on a deep, meaningful rapport with his towels, soap, stuffed animals, dirty laundry, etc.
# 5	0	0	0.681	The shaky, wandering, hand-held camera-work was another annoying feature I could have done without.
# 6	0	0	0.600	And if that isn't enough to make you puke in your popcorn, we hear the old 60's ode "California Dreaming" by the Mamas and Papas blaring over the soundtrack over and over again during a particularly lengthy sequence.<br /><br />Quentin Tarantino was responsible for bringing this loser to America through his Rolling Thunder Productions company, though I cannot for the life of me figure out why a man with his talent would bother.
# 7	1	1	0.533	He was known to have remarked, "I'm happy to love a movie this much."
# *8	1	1	0.616	A lot of us, though, hope he will concentrate on making his audiences happy with more worthwhile discoveries in the future.
# 1.36356470012 A lot of us, though, hope he will concentrate on making his audiences happy with more worthwhile discoveries in the future.
# ----------------------------------------
# Doc: 24
# Target: 0
# ID	Pred	ExpertPred	Score	text
# 0	0	0	0.622	I should have trusted my instincts better: No expectations - no disappointments.
# 1	0	0	0.629	Instead, however, I expected to experience a similar masterpiece like Koyaanisqatsi (1983) and was brutally disappointed.
# 2	0	0	0.636	Powaqqatsi is in my humble opinion nothing but a cheap attempt to cash in on the cult success of its predecessor, and - artistically - it fails miserably.
# 3	0	0	0.583	It appears some producer gathered up leftover material from Koyaanisqatsi, hurriedly threw it together, placed everything in slow motion and got some pop entertainer under the pseudonym of Philip Glass to hurriedly throw together some banal background music, which is incessantly repeated.
# 4	0	0	0.675	Where Koyaanisqatsi entertains the viewer with clever fast and slow motion changes, Powaqqatsi is one long sequence of mundane images in slow-motion (if you view them on your VCR in fast preview mode, you'll see what I mean).
# 5	0	1	0.603	What disappointed me the most, however, was Philip Glass's soundtrack.
# 6	0	1	0.590	I couldn't - and still can't - believe that these commercial-sounding New Age type drones, which could easily have been composed in one afternoon by any 14-year-old on a Casio calculator, were from the same composer who so brilliantly composed the emotional and perfectly-synchronized music for Koyaanisqatsi.
# *7	0	0	0.714	All in all, a big waste of time!
# 8	0	0	0.591	My advice: Forget commercialism!
# 9	0	0	0.545	Watch Koyaanisqatsi again instead!
# 1.61530520288 All in all, a big waste of time!
# ----------------------------------------
# Doc: 25
# Target: 1
# ID	Pred	ExpertPred	Score	text
# 0	0	1	0.580	This is the kind of film you want to see with a glass of wine, the fire on, and with your feet up.
# *1	0	0	0.713	It doesn't require that much brain-power to follow, so is very good after a long day.
# 2	0	0	0.563	I would say it is very unrealistic - if you expecting anything serious, then don't bother, but it is very funny.
# 3	0	1	0.646	Just the thought that a businessman would go so far as to agree to live in a slum for a while, and then actually get to enjoy it...
# 4	1	1	0.545	I would definitely recommend it.
# 1.60107788684 It doesn't require that much brain-power to follow, so is very good after a long day.
# ----------------------------------------
# Doc: 26
# Target: 1
# ID	Pred	ExpertPred	Score	text
# 0	1	1	0.524	I've had this movie on tape for years and started watching it again this morning (while waiting for my laundry --- how ironic!)
# 1	0	0	0.613	mostly because I wanted to hear Benjamin Frankel's title music again.
# 2	0	0	0.564	I ended up sitting through about the first half hour, entranced by how wonderfully assured the direction, writing, and performances are.
# 3	0	1	0.567	The movie is like a who's who of 50s British character stars: Cecil Parker, Michael Gough, Miles Malleson, Duncan Lamont, and particularly Ernest Thesiger, great as the dessicated old giant of the textile mills.
# *4	0	1	0.626	Not to mention Alec Guinness and Joan Greenwood, not character players as such but charming, charismatic leads.
# 5	0	1	0.531	This is science fiction in its purest form and droll comedy as well.
# 6	0	0	0.622	An all-time classic, and I hope no one ever tries to remake it!
# 0.314225762201 Not to mention Alec Guinness and Joan Greenwood, not character players as such but charming, charismatic leads.
# ----------------------------------------
# Doc: 27
# Target: 1
# ID	Pred	ExpertPred	Score	text
# *0	1	1	0.612	I recently watched Caprica again and thought I might as well come and write up a review!
# 1	1	1	0.520	I first saw this right after I saw the series finale of Battlestar Galactica ( Being a big drooling fan boy of the show left me clinging onto anything I could of the shows universe )so I didn't know what to expect...but I did come out with a smile though I must admit...<br /><br />The story starts off dramatically on planet of caprica and we are introduced with a variety of interesting characters...I won't give too much away but there is a dramatic event that dictates the course of the story but I suggest you watch this.<br /><br />Must say...Esai Morales is one hell of an actor he pulled off a young Joseph Adama...(father of the Admiral in Battlestar Galactica)I found his acting spot on and I could believe that he is the father of William Adama from BSG...<br /><br />Also Eric Stoltz fits his role precisely...!
# 2	0	1	0.591	Special note it was good to see Polly Walker outside of Rome!
# 3	1	1	0.559	Don't sit down and watch Caprica with the expectation of it being like Battlestar Galactica because the story line is pretty straight forward and anyone can watch it..without having to have see BSG!.<br /><br />This show is a well written drama for those who like there drama with a bit of a sci-fi kick!
# 1.29023154384 I recently watched Caprica again and thought I might as well come and write up a review!
# ----------------------------------------
# Doc: 28
# Target: 0
# ID	Pred	ExpertPred	Score	text
# *0	0	0	0.618	from the start of this movie you soon become aware that the name of the film has nothing to do with the movie itself from watching a naked woman being chased by people in very silly masks to servants running round in the worst clothing I've ever seen and all this in subtitles makes this the kind of movie you should think twice about seeing and as the film slowly moves along you soon realise that the vampire is not a vampire you got to wonder where the title came from some parts of the film made a bit of sense with Pierre and is father but as the film gets to its really silly ending you have got to think why end a film this way and surly they had a better ending if only in there heads this is not a film to watch basically
# 0.208759372741 from the start of this movie you soon become aware that the name of the film has nothing to do with the movie itself from watching a naked woman being chased by people in very silly masks to servants running round in the worst clothing I've ever seen and all this in subtitles makes this the kind of movie you should think twice about seeing and as the film slowly moves along you soon realise that the vampire is not a vampire you got to wonder where the title came from some parts of the film made a bit of sense with Pierre and is father but as the film gets to its really silly ending you have got to think why end a film this way and surly they had a better ending if only in there heads this is not a film to watch basically
# ----------------------------------------
# Doc: 29
# Target: 0
# ID	Pred	ExpertPred	Score	text
# 0	0	0	0.651	As someone else mentioned, it begins with a bizarre prologue about a little blond girl killing a cat.
# 1	0	1	0.561	Then the main story: a photographer (Gaffari) and a writer (Shepard) meet by chance and take a trip into the mountains.
# ...
# 9	0	1	0.565	)<br /><br />Watch Sarah Silverman's show.
# 10	1	1	0.531	This kind of stuff is the future of entertainment.
# 1.47323364499 If you can't appreciate the offbeat humor it offers, the show probably isn't for you.
# ----------------------------------------
# Doc: 93
# Target: 0
# ID	Pred	ExpertPred	Score	text
# 0	0	0	0.619	Three giant sabretooth tigers(..created in a laboratory from mitochondrial DNA, a "genetic breakthrough" derived from fossil material)are on the rampage accidentally set free through a series of events(such as a computer geek's introduced virus in order to unlock security measures keeping the resort novelty shops closed during construction & a security guard's leaving a gate open while searching for the missing page from a porn mag that flew away in the breeze)that threaten the lives of those it comes in contact with.
# 1	0	0	0.641	The tigers are always hungry, but are unable to digest what they eat.
# 2	0	0	0.635	So pretty much the tigers just rip their prey to shreds.
# 3	0	0	0.588	Victims include a group of college kids(..the stereotypes include a goth girl, jock and tech nerd), security personnel, and those somewhat developed rich scoundrels who we can easily despise and wish horrible death.<br /><br />Rounding out a series of bad sci-fi channel flicks, Attack of the Sabretooth has some of the most wretched computer simulated animals I've seen yet.
# 4	0	0	0.689	And, the final death sequence is so putridly presented, you'll demand within the deepest recesses of your soul the time spent on this truly awful exercise in the creature feature canon.
# *5	0	0	0.709	There's some good dark humor deriving from heads being torn from necks, but even here the prosthetic work is unconvincing.
# 6	0	0	0.557	Prosthetic body parts and blood aplenty as victims are pounced upon, crying for help and receiving none.
# 7	0	0	0.640	I'm starting to sound like a broken record, repeating myself in every user comment I write for these sci-fi channel flicks.
# 8	0	1	0.675	I think maybe it's time to move on to other kinds of cinema.
# 9	0	0	0.527	Robert Carradine has a role as a ruthless businessman who is being wooed by his truly repellent ex-brother-in-law, Nicholas Bell, the one opening "Primal Park", a resort / zoo featuring genetically created sabretooth tigers as it's major attraction.
# 10	0	0	0.628	Stacy Haiduk, still quite yummy, is a security officer who attempts to convince Bell to get the investors he hopes to goad into putting money in his multi-million dollar project to leave the island.
# 11	0	0	0.527	Brian Wimmer is Haiduck's lover and his role is a mechanic keeping operations running smoothly.<br /><br />Bell's fate at the end, resulting from a dislodged tooth from a sabretooth tiger statue is the pits.
# 12	0	1	0.556	Carradine spends a great deal of the film taunting Bell, his arch nemesis.
# 13	0	1	0.602	The tiger's point-of-view shows humans in a bright color as it moves towards them.
# 14	0	0	0.653	The film ultimately consists of characters walking through darkened corridors(..the tech nerd's virus cut off the power)worried for their safety.
# 15	0	1	0.599	The college kids commit breaking and entering to score certain items needed(..it's a scavenger hunt type of activity)to enter a fraternity / sorority.
# 16	0	0	0.635	The cast playing these kids do not rise above their clichÃ©s.
# 1.54596357079 There's some good dark humor deriving from heads being torn from necks, but even here the prosthetic work is unconvincing.
# ----------------------------------------
# Doc: 94
# Target: 0
# ID	Pred	ExpertPred	Score	text
# 0	0	0	0.538	Omen IV: The Awakening starts at the 'St.
# 1	0	0	0.629	Frances Orphanage' where husband & wife Karen (Faye Grant) & Gene York (Michael Woods) are given a baby girl by Sister Yvonne (Megan Leitch) who they have adopted, they name her Delia.
# 2	0	1	0.530	At first things go well but as the years pass & Delia (Asia Vieria) grows up Karen becomes suspicious of her as death & disaster follows her, Karen is convinced that she is evil itself.
# 3	1	0	0.502	Karen then finds out that she is pregnant but discovers a sinister plot to use her as a surrogate mother for th next Antichrist & gets a shock when she finds out who Delia's real father was...<br /><br />Originally to be directed by Dominique Othenin-Girard who either quit or was sacked & was replaced by Jorge Montesi who completed the film although why he bothered is anyone's guess as Omen IV: The Awakening is absolutely terrible & a disgrace when compared to it illustrious predecessors.
# 4	0	0	0.721	The script by Brian Taggert is hilariously bad, I'm not sure whether this nonsense actually looked good as the written word on a piece of paper but there are so many things wrong with it that I find even that hard to believe.
# 5	0	0	0.569	As a serious film Omen IV: The AWakening falls flat on it's face & it really does work better if you look at it as a comedy spoof, I mean the scene towards the end when the Detective comes face-to-face with a bunch of zombie carol singers who are singing an ominous Gothic song has to be seen to be believed & I thought it was absolutely hilarious & ridiculous in equal measure.
# 6	0	0	0.629	Then there's the pointless difference between this & the other Omen films in that this time it's a young girl, the question I ask here is why?
# 7	0	0	0.704	Seriously, why?
# *8	0	0	0.813	There's no reason at all & isn't used to any effect at all anyway.
# 9	0	0	0.602	Then of course there's the stupid twist at the end which claims Delia has been keeping her brother's embryo inside herself & that in a sinister conspiracy involving a group of Satan worshippers it has been implanted in Karen so she can give birth to the Antichrist is moronic & comes across as just plain daft.
# 10	0	0	0.762	At first it has a certain entertainment value in how bad it is but the unintentional hilarity gives way to complete boredom sooner rather than later.<br /><br />It's obviously impossible to know how much of Omen IV: The Awakening was directed by Girard & Montesi but you can sort of tell all was not well behind the camera as it's a shabby, cheap looking poorly made film which was actually made-for-TV & it shows with the bland, flat & unimaginative cinematography & production design.
# 11	0	0	0.659	Then there's the total lack of scares, atmosphere, tension & gore which are the main elements that made the previous Omen films so effective.<br /><br />The budget must have been pretty low & the film looks like it was.
# 12	0	1	0.570	The best most stylish thing about Omen IV: The Awakening is the final shot in which the camera rises up in the air as Delia walks away into the distance to reveal a crucifix shaped cross made by two overlapping path's but this is the very last shot before the end credits roll which says just about everything.
# 13	0	0	0.609	I have to mention the music which sounds awful, more suited to a comedy & is very inappropriate sounding.
# 14	0	0	0.581	The acting is alright at best but as usual the kid annoys.<br /><br />Omen IV: The Awakening is rubbish, it's a totally ridiculous film that tries to be serious & just ends up coming across as stupid.
# 15	0	0	0.715	The change of director's probably didn't help either, that's still not a excuse though.
# 16	0	0	0.598	The last Omen film to date following the original The Omen (1976), Damien: Omen II (1978) & The Final Conflict (1981) all of which are far superior to this.
# 3.07390128897 There's no reason at all & isn't used to any effect at all anyway.
# ----------------------------------------
# Doc: 95
# Target: 0
# ID	Pred	ExpertPred	Score	text
# 0	0	0	0.700	Yes, Kazaam is one of those horribly bad movies that almost reminds one of everything that is wrong with not just kids movies, but with humanity.
# 1	0	0	0.644	Here we have Shaq as a rapping genie- yes, a RAPPING genie- where he does everything from making bad puns to dressing in ridiculous outfits, all ending in him in a Christ-like pose with lots of light surrounding him.
# 2	0	0	0.566	So, yeah, expect really cheesy bits, including the first wish being a lot of junk food falling down from the sky (and, regrettably, not knocking out the two main characters, particularly the kid).
# 3	1	0	0.520	What might not be expected is that a film with a kid and Shaquille O'Neill would be so incredibly schmaltzy!
# 4	1	0	0.500	The main plot of the film involves this kid, played in that all-too-typical and annoying-kid fashion by the great-grandson of Frank Capra (where in which the kid is yelling out his dialog angrily), who comes upon a genie who's been trapped in a boom-box.
# 5	0	0	0.610	Then "hiarity ensues" as the kid makes the Shaq-genie his quasi-slave as he waits on his last two wishes as he tries to make amends with his shady-gang-type absentee father.<br /><br />This really sappy, contrived son and father story would be bad enough, as there are certain lines that have been uttered in a million other movies (i.e.
# 6	0	1	0.518	the "two chances in life" speech from father to son).
# 7	0	1	0.506	But it's Shaquille O'Neill who is both the reason to watch the film (ironically), and the obvious sinking crux of it all.
# 8	0	0	0.621	His plot line involves him, when not getting the over-talky treatment from Capra, to rap within the dialog and also start off his blossoming recording career.
# 9	0	0	0.520	On top of this, he also kicks ass and takes names with the main bad guys who want him back in the boom-box.
# 10	0	0	0.578	So is there a camp factor to the movie?
# 11	0	0	0.543	Up to a point, but this is even squashed by all of the mushy scenes and 'heart-felt' moments that have really no business with the rest of the material.
# 12	0	0	0.671	One might ask if the people making the movie, who were obviously doing it at the behest of the popularity of a BASKETBALL player who wanted to go on the Michael Jordan acting bandwagon, if it would be anywhere near decently entertaining or convincing.
# *13	0	0	0.720	I'd hope that they too knew they were just getting paid.
# 14	0	0	0.570	But I'd hope even more that they felt at least a little guilty afterwords for feeding the Shaq-machine.<br /><br />So, if you want to have a fun night of Shaq as genie-turned-rapper-turned-wisecracker, all the more fun to you.
# 15	0	0	0.553	Hell, it might even be interesting to have a Shaq movie night with this and his other critically acclaimed effort Steel.
# 16	0	0	0.653	But if you're hoping to keep a few brain cells, stay away from what is very likely the worst flick of 1996, and a candidate among many others for worst of the 90's.
# 1.7062243808 I'd hope that they too knew they were just getting paid.
# ----------------------------------------
# Doc: 96
# Target: 0
# ID	Pred	ExpertPred	Score	text
# 0	0	0	0.637	After watching this thing, then reading the summary on the back of the DVD, then thinking back to actual movie....I became a bit dizzy.
# 1	0	0	0.584	I thought, maybe I fell asleep and dreamed I was a down syndrome baby waltzing through a never ending forest where people drive 11 miles an hour and stop for no purpose other then occasional tasteless lesbianism.
# 2	0	0	0.623	Where (zombies?)
# 3	0	0	0.515	come out of nowhere and (vampires?)
# 4	0	1	0.592	who (seduce?)
# 5	0	0	0.608	pure hearted citizens on their way to save the world.
# 6	0	0	0.606	Neither zombie nor vampire notably encounter each other.
# 7	0	0	0.645	The only fighting i remember was getting that walrus Bonny Giroux's panties off.
# 8	0	0	0.608	Coo Coo ca FAT!
# 9	0	0	0.557	All of them!
# 10	0	0	0.624	Maybe that was because we were watching it widescreen stretched and were too lazy to change it to its native resolution, but that actually made it more entertaining...
# 11	0	0	0.599	In conclusion my trailing thought thesis had more continuity, plot, character development, antagonism, subject matter, and acting then the entirety of this film.
# *12	0	0	0.681	It made Bloodrayne look like Citizen F***ING KANE
# 1.12983596881 It made Bloodrayne look like Citizen F***ING KANE
# ----------------------------------------
# Doc: 97
# Target: 1
# ID	Pred	ExpertPred	Score	text
# 0	0	1	0.516	I hadn't heard about Brashear before I watched this.
# 1	0	1	0.537	This is the story of him and the man who trained him, helping him to become the first African-American US Navy Diver.
# 2	1	1	0.525	A tale of will-power.
# 3	1	1	0.556	The plot is well-written, and develops nicely throughout.
# 4	0	0	0.627	This is what it seems, the typical underdog thing, and it doesn't hold too many surprises.
# 5	0	1	0.672	It's also quite Hollywood, but hey, I don't know the actual man, maybe it's close to how it actually happened.
# 6	0	1	0.530	Nevertheless, it gets the job done, with dramatic scenes and adversity along the way, and this is inspirational for anyone who's ever heard the words "no, you can't" be spoken about their life-long dream.
# 7	1	1	0.560	The acting performances are all excellent.
# 8	0	1	0.552	DeNiro and Gooding Jr. both shine whenever they're on-screen.
# 9	1	1	0.512	Rapaport is marvelous, as well.
# 10	1	1	0.570	The characters are well-written, credible and consistent.
# 11	0	1	0.509	This is well-edited, and features good cinematography.
# 12	0	1	0.590	The production values are high, and this does a fairly convincing job of transporting us back to the 50's.
# 13	0	0	0.510	This is the only film I've seen by this director and the writer, though I may now consider looking into more they're responsible for.
# *14	0	0	0.688	There is a moderate amount of strong language, otherwise no offensive material.
# 15	1	1	0.598	I recommend this to anyone who finds the subject interesting, and/or fans of those who made it.
# 16	1	1	0.567	7/10
# 1.22879963182 There is a moderate amount of strong language, otherwise no offensive material.
# ----------------------------------------
# Doc: 98
# Target: 1
# ID	Pred	ExpertPred	Score	text
# 0	1	1	0.525	I had never heard of this film before a couple of weeks ago, but its concept interested me when I heard it: an American man meets a European woman on his last night in Europe and they spend the night together talking.
# 1	0	1	0.537	It sparked my interest, but I never expected it to be this great.
# 2	1	1	0.590	Before Sunrise is a masterpiece, and it's also one of the most romantic films on record.
# 3	0	1	0.530	To my surprise, it completely lacked the cynicism of the 1990s.
# *4	0	0	0.735	It's impossible to really talk too much about it, since there is no real plot, so to speak (although there are plenty of thoroughly interesting things you could talk about; it is sort of like My Dinner With Andre, where there is a conversation, but it's not JUST the conversation that matters), but let me just say, see it.
# 5	0	1	0.618	SEE IT!
# 1.92449591834 It's impossible to really talk too much about it, since there is no real plot, so to speak (although there are plenty of thoroughly interesting things you could talk about; it is sort of like My Dinner With Andre, where there is a conversation, but it's not JUST the conversation that matters), but let me just say, see it.
# ----------------------------------------
# Doc: 99
# Target: 1
# ID	Pred	ExpertPred	Score	text
# 0	1	1	0.552	Kurosawa, fresh into color, losses sight of his usual themes of truth and perception of reality and opts for a depressing take on Tokyo's slums.
# 1	0	1	0.616	Kurosawa stretches for a style that was, in my opinion, his antithesis- that is to say, I feel as if Kurosawa wanted to make an Ozu picture.
# *2	0	0	0.662	Poorly paced, poorly conceived, this movie is a rare dud in this auteur body of excellent work.
# 3	0	0	0.583	While Ikiru, while being mundane and depressing, was still interesting and well paced, and while Stray Dog depicted the slums and social poverty of Japan without being too heavy handed or boring, do desu ka den has all the somberness that one could expect with its content, with none of the redeeming qualities of earlier Kurosawa pictures.<br /><br />Be warned, this is not a movie that Kurosawa should be judged by.
# 0.846428356858 Poorly paced, poorly conceived, this movie is a rare dud in this auteur body of excellent work.
# 1130

# %%
# Doc, Target, ID,	Pred,	ExpertPred,	Score,	text

r =  print_document_senteces(data.train, st, rnd_docs)
# no_m = [x for x in r if ]
print "Total:", len(r)
print "Student Pred 0:",len([x for x in r if x[3] == 0])
print "True 0:", len([x for x in r if x[1] == 0])
print "Expert Pred 0:",len([x for x in r if x[4] == 0])
print "Boostrap: ", data.train.target[initial].sum()
# Out:
# Total: 1130
# Student Pred 0: 924
# True 0: 581
# Expert Pred 0: 589
# Boostrap:  95

# %%
from sklearn.metrics import accuracy_score

data.test.bow = vct.transform(data.test.data)
# Out:
# student 0.6806
# expert 0.88344

# %%
from sklearn.metrics import confusion_matrix

# test = st.model.predict(data.test.bow)
# print "student accuracy on test",  accuracy_score(data.test.target, test)
# print "expert accuracy on test",  accuracy_score(data.test.target, expert.predict(data.test.bow))
# print "Total test instances", len(data.test.target)
print
print "Expert Accu on rnd docs: %.3f (%s / %s)" % (accuracy_score([x[1] for x in r], [x[4] for x in r]), len([x for x in r if x[4] == x[1]]), len(r))
print "Student Accu on rnd docs:  %.3f (%s / %s)" % (accuracy_score([x[1] for x in r], [x[3] for x in r]) ,len([x for x in r if x[3] == x[1]]), len(r))

print "CM Student"
print confusion_matrix([x[1] for x in r], [x[3] for x in r])
# print confusion_matrix(data.test.target, test)
print "CM Expert"
print confusion_matrix([x[1] for x in r], [x[4] for x in r])
# print confusion_matrix(data.test.target, expert.predict(data.test.bow))
# Out:
# Expert Accu on rnd docs: 0.699 (790 / 1130)
# Student Accu on rnd docs:  0.564 (637 / 1130)
# CM Student
# [[506  75]
#  [418 131]]
# CM Expert
# [[415 166]
#  [174 375]]

# %%
# Doc, Target, ID,	Pred,	ExpertPred,	Score,	text., selected

# Selected sentences of each document

f = [s for s in r if s[7] == True]
for s in f[:10]:
    print s[0], s[2], s[3], s[4], s[5], s[6], s[7]
# Out:
# 0 3 0 1 0.64874573302 i wouldn't exactly call it grand and unforgettable cinema and it doesn't seem quite as memorable as the director's first movie "cube" but it's a good pit of fluff to watch on a Sunday morning. True
# 1 0 1 1 0.554804503965 I was so glad I came across this short film. True
# 2 0 0 0 0.655159463136 The premise is a bit better than the execution, but that doesn't mean the film is worth a look. True
# 3 11 0 0 0.659205811671 Heflin was just coming off his Oscar for Johnny Eager the previous year and he and Garland wouldn't appear to be an ideal screen team, but they're not bad together.<br /><br />Presenting Lily Mars is a fine showcase for the talents of Judy Garland. True
# 4 1 0 0 0.828533101058 Why did they discontinue it? True
# 5 5 0 0 0.840975224212 Don't waste your time with this one because it's bad. True
# 6 0 0 0 0.683434972416 This movie is just so good! True
# 7 2 1 1 0.685708823515 The original Chinese dialog heightens the emotional intensity of the performances and the story.<br /><br />This is a MUST SEE -- enjoyable family film, although not for very young children. True
# 8 10 1 0 0.642745440975 Plus, how does she have that strength at the end of the movie when she starts killing people? True
# 9 3 0 0 0.702326480393 The entire premise that so much money was given a team of investigators to solve murders dating back 10-20-30 or even 60 years seems so unlikely.<br /><br />The time is also a factor as they only have 50-60 min to tell the story which means that they get a break through just in the nick of time to solve the case and bring justice to surviving family members, if they are still alive. True

# %%
print "Correct labeled (expert):", len([s for s in f if s[1] == s[4]]), "out of ", len(f)
print "Correct predicted (student):", len([s for s in f if s[1] == s[3]]), "out of ", len(f)
print 
print "CM of Expert on selected sentences"
print "Accuracy: %.3f" % accuracy_score([x[1] for x in f], [x[4] for x in f])
print confusion_matrix([x[1] for x in f], [x[4] for x in f])

print "CM of Student on selected sentences"
print "Accuracy: %.3f" % accuracy_score([x[1] for x in f], [x[3] for x in f])
print confusion_matrix([x[1] for x in f], [x[3] for x in f])
# Out:
# Correct labeled (expert): 70 out of  101
# Correct predicted (student): 57 out of  101
#
# CM of Expert on selected sentences
# Accuracy: 0.693
# [[41  6]
#  [25 29]]
# CM of Student on selected sentences
# Accuracy: 0.564
# [[41  6]
#  [38 16]]

# %%
## 
data.train.remaining = rnd.permutation(len(data.train.target))
## random bootstrap 
data.train.data = np.array(data.train.data, dtype=object)
initial = rnd.choice(data.train.remaining, 200, replace=False)
st.fit(data.train.bow[initial], data.train.target[initial], doc_text=data.train.data[initial])
