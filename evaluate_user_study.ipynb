# %% [markdown]
# # Evalutate Student
#
# We use the user studies collected labels to test both first and SR students
#
# The procedure requires:
#
# * load the data using the same configuration
# * Get the VCT to process the doucments saved in the results
# * create a loop to train the student and graph the curves
# * Save curves on files

# %%
## Imports 
# %matplotlib inline
STRUCTURED = '../structured'
IMDB_DATA = 'C:/Users/mramire8/Documents/Research/Oracle confidence and Interruption/dataset/aclImdb/raw-data'
SRAA_DATA = 'C:/Users/mramire8/Documents/Research/Oracle confidence and Interruption/dataset/sraa/sraa/sraa/partition1/data'
ARXIV_DATA= 'C:/Users/mramire8/Documents/Datasets/arxiv'

IMDB_DATA = '/Users/maru/MyCode/data/imdb'
SRAA_DATA = '/Users/maru/MyCode/data/sraa'

# STRUCTURED = '/Users/maru/My Code/structured'
# IMDB_DATA='/Users/maru/Dataset/aclImdb'
# SRAA_DATA='/Users/maru/Dataset/aviation/data'
# TWIITER_DATA = '/Users/maru/Dataset/twitter'

import sys
import os
# sys.path.append(os.path.abspath(STRUCTURED))
import utilities.experimentutils as exputil
import utilities.datautils as datautil
import numpy as np
import nltk
from sklearn import metrics
import matplotlib.pyplot as plt
import matplotlib as mpl


def load_data(dataname, path, categories=None):
    import pickle

    DATA_PKL = path + '/data_u.pkl'

    if os.path.isfile(DATA_PKL):
        vct, data = pickle.load(open(DATA_PKL, 'rb'))
    else:
        vct = exputil.get_vectorizer({'vectorizer':"bow", 'limit':2, 'min_size':100})
        data = datautil.load_dataset(dataname, path, categories=categories, rnd=876543210, shuffle=True, keep_subject=True)
        data.train.data = np.array(data.train.data, dtype=object)
        data.test.data = np.array(data.test.data, dtype=object)
        data.train.bow = vct.fit_transform(data.train.data)
        data.test.bow = vct.transform(data.test.data)
        pickle.dump((vct, data), open(DATA_PKL, 'wb'))

    return data, vct

# Get the sentences 
def _sentences(docs, doc_labels, sent_tk):
    data = []
    true_labels = []
    sent = sent_tk.tokenize_sents(docs)
    for sentences, doc_label in zip(sent, doc_labels):
        data.extend(sentences)
        true_labels.extend([doc_label] * len(sentences))
    return data, np.array(true_labels), sent

# %%
from collections import defaultdict

def to_float(x):
    f = x
    try:
        f = float(x)
    except:
        f = x
    return f

def read_data(filename, measure='expert', annotation_time=False):
#Labels: doc_index	true_label	exp_label	doc_text
    if not os.path.isfile(filename):
        raise Exception("Oops, no file")
        
    f = open(filename)
    with f:
        lines = f.readlines() 
    print "Number of fields:", len(lines[0].split("\t"))
    print "Number of records:", len(lines)-1
    data_all =  [l.strip().split("\t") for l in lines[1:]] #discard first lines
    data = np.array([[to_float(x) for x in row[:-1]] for row in data_all])
    index = [float(d[0]) for d in data]
    true = [float(d[1]) for d in data]
    expert = [float(d[2]) for d in data]
    time = []
    doc_text = np.array([row[-1] for row in data_all])
    if annotation_time:
        time = [float(d[3]) for d in data]
        len_snip = [row[-2].split() for row in data_all]
        len_snip = [len(r) for r in len_snip]
        return index, true, expert, doc_text, time, len_snip
    return index, true, expert, doc_text, time

def read_text(filename):
#Labels: doc_index	true_label	exp_label	doc_text
    if not os.path.isfile(filename):
        raise Exception("Oops, no file")
        
    f = open(filename)
    with f:
        lines = f.readlines() 
    print "Number of fields:", len(lines[0].split("\t"))
    print "Number of records:", len(lines)-1
    data_all =  [l.strip().split("\t") for l in lines[1:]] #discard first lines
    doc_text = np.array([row[-1] for row in data_all])
    doc_snip = np.array([row[-2] for row in data_all])

    return doc_text, doc_snip

# %%
IMDB_DATA = 'C:/Users/mramire8/Documents/Research/Oracle confidence and Interruption/dataset/aclImdb/raw-data'
#IMDB_DATA = '/Users/maru/MyCode/data/imdb'
imdb, vct = load_data("imdb", IMDB_DATA)

# %%
clf = exputil.get_classifier('lrl1', parameter=1)

#results of frist1 and sr-pc
# DATA = "/Users/maru/Google Drive/AAL-Experiments/firstk-journal/results/user_study_0_v2"
DATA = "C:/Users/mramire8/Google Drive/AAL-Experiments/firstk-journal/results/user_study_0_v2"

f1_index, f1_true, f1_expert, f1_text, f1_time, f1_len  = read_data(DATA + "/imdb-rnd-first1-expert2-labels.txt", annotation_time=True)
sr_index, sr_true, sr_expert, sr_text, sr_time, sr_len = read_data(DATA + "/imdb-rnd-sr-expert1-labels.txt", annotation_time=True)
bt_index, bt_true, _, bt_text, _ = read_data(DATA + "/imdb-rnd-sr-student-labels.txt")
# Out:
# Number of fields: 7
# Number of records: 200
# Number of fields: 7
# Number of records: 200
# Number of fields: 4
# Number of records: 204

# %%
# get the labels in the corresponding order
f1_target = [f1_expert[f1_index.index(i)] for i in sr_index]

# this step is not necessary, it should return the same order
sr_target = [sr_expert[sr_index.index(i)] for i in sr_index]

eval_seq = [f1_index.index(i) for i in sr_index]

# %%
## Get the training documents ready fro evaluation
train_tx = bt_text[:50]
train_tx = np.append(train_tx, sr_text)
train_bow = vct.transform(train_tx)
train_target= bt_true[:50]
# train_target.extend(sr_target)
# train_target.extend(f1_target)

# %%
len(train_tx)
# Out:
# 250

# %%
from sklearn import metrics

def get_classifier(clf_name, parameter):
    clf = None
    try: 
        clf = exputil.get_classifier(clf_name, parameter=parameter)
    except ValueError:
        if clf_name == 'svc':
            from sklearn.svm import SVC 
            clf = SVC()
        elif clf_name == 'lr-cw':
            from sklearn.linear_model import LogisticRegression
            clf = LogisticRegression(class_weight={0:.45, 1:.55})
        else: 
            raise ValueError("Oops try other classifier")
    return clf
            
def evaluate_student(clf_name, train_bow, train_target, test,parameter=1):
    x = range(50, len(train_target)+1, 1)
    accuracy = []
    
    for step in x: 
        target_y = np.array(train_target[:step])
        train_x = train_bow[:step]
        non_neutral = target_y < 2
        clf = get_classifier(clf_name, parameter)
        clf.fit(train_x[non_neutral], target_y[non_neutral])
        predicted = clf.predict(test.bow)
        acc = metrics.accuracy_score(test.target, predicted)
        accuracy.append(acc)
#         print step, acc
    return x, accuracy

# %%
test = get_classifier('lrl1', 10)
print test
# Out:
# LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, penalty='l1', random_state=None, tol=0.0001)

# %% [markdown]
# # Student Evaluation
#
# Evaluate the student using the labels gathered with the user study
#
# * Bootstrap: 50 documents
# * Step: 1
# * Methods: first-1 and SR
# * Budget: 200 queries
# * Sequence: Random

# %%
# Evaluate SR
train_target= bt_true[:50]
train_target.extend(sr_target)
x, y_sr = evaluate_student('lrl1',train_bow, train_target, imdb.test)

#Evaluate First1
train_target= bt_true[:50]
train_target.extend(f1_target)
x, y_f1 = evaluate_student('lrl1',train_bow, train_target, imdb.test)

#Evaluate True
train_target= bt_true[:50]
train_target.extend(sr_true)
x, y_true = evaluate_student('lrl1',train_bow, train_target,imdb.test)

# %%
mpl.style.use('fivethirtyeight')

def plot_eval(x_all, y_all, labels=None, name='fig.png'):
    fig = plt.figure(figsize=(8,6))
#     i = range(0, len(x_all))
    for l,x,y in zip(labels, x_all, y_all):
        plt.plot(x,y, label=l)
    plt.xlabel("Number of Queries")
    plt.ylabel("Accuracy")
#     plt.ylim([.55,.75])
    plt.legend(loc='best')
    plt.savefig(name,bbox_inches="tight", dpi=200, transparent=True)

# %%
plot_eval([x,x,x], [y_f1, y_sr, y_true], labels=['first-1','sr-pc', 'true'], name='student_human.png')

# %% [markdown]
# # Evaluating Other Classifiers
#
# Try other classifiers with the same data as the student evaluation from the user study. Does a different classifier perform better than lrl1?
#
# The data representation doesn't change. binary BOW.
#
#
# Classifiers to try:
#
# * lr-l1 with other c values
# * SVC with default paramters
# * MNB with alpha=1
# * lr-l1 with class weights
#
# The following experiments use the following settings:
#
# * classifier
# * bootstrap: 50
# * step: 1
# * labels: true labels

# %%
#Evaluate MNB
# train_target= bt_true[:50]
# train_target.extend(sr_true)
# x, y_mnb = evaluate_student('mnb',train_bow, train_target,imdb.test, parameter=.5)

#Evaluate lrl1-C=10
# train_target= bt_true[:50]
# train_target.extend(sr_true)
# x, y_l110 = evaluate_student('lrl1',train_bow, train_target,imdb.test,parameter=100)

#Evaluate SVC 
# train_target= bt_true[:50]
# train_target.extend(sr_true)
# x, y_svc = evaluate_student('svc',train_bow, train_target,imdb.test,parameter=10)

#Evaluate class weighted LR
train_target= bt_true[:50]
train_target.extend(sr_true)
x, y_cw = evaluate_student('lr-cw',train_bow, train_target,imdb.test, parameter=1)

# %%
plot_eval([x,x,x,x,x], [y_true, y_mnb, y_l110, y_svc, y_cw], labels=['lr-l1-c=1','mnb', 'lrl1-c100', 'svc','lr-cw'], name='student_human.png')

# %%
# nb = get_classifier('svc',100)
# nb.fit(train_bow, train_target)
# print metrics.accuracy_score(imdb.test.target, nb.predict(imdb.test.bow))
# from sklearn.naive_bayes import MultinomialNB
# nb = MultinomialNB(alpha=.50)
# nb.fit(train_bow, train_target)
# print metrics.accuracy_score(imdb.test.target, nb.predict(imdb.test.bow))
# from sklearn.linear_model import LogisticRegression

nb = LogisticRegression(class_weight={0:.45, 1:.55})
nb.fit(train_bow, train_target)
print metrics.accuracy_score(imdb.test.target, nb.predict(imdb.test.bow))
# Out:
# 0.760574652847

# %%
from scipy import stats
print "True vs. rest"
# print "t-statistic: %f, p-value: %f" % stats.ttest_ind(y_true, y_f1)
print "MNB: t-stat: %f, p-value: %f" % stats.ttest_rel(y_true, y_mnb)
print "LR-L1-C=10: t-stat: %f, p-value: %f" % stats.ttest_rel(y_true, y_l110)
print "SVC: t-stat: %f, p-value: %f" % stats.ttest_rel(y_true, y_svc)
# Out:
# True vs. rest
# MNB: t-stat: 24.812439, p-value: 0.000000
# LR-L1-C=10: t-stat: -5.433085, p-value: 0.000000
# SVC: t-stat: 51.350927, p-value: 0.000000

# %% [markdown]
# # Testing other sentence picking methods
#
# Try different ways pick sentences for the labes of the oracle:

# %%
def pick_max_feat(doc_sents, clf):
    print doc_sents.shape
    max_vals = np.argmax(doc_sents, axis=1)[::-1]
    return max_vals[0]

# def pick_sentiment(doc_sents):
#     # load sentiment
#     # if any word exists in the sentiment
#     # return value?
#     pass 

def select_snippet(text, target, vct, n=10):
    sent_tk = nltk.data.load('tokenizers/punkt/english.pickle')
    sents = sent_tk.tokenize_sents(text[:n])
    for doc in sents:
        doc_bow= vct.transform(doc)
        picked = sents[pick_max_feat(doc_bow, None)]
        print picked
        
select_snippet(train_tx, train_target, vct)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-981bda444308> in <module>()
#      18         print picked
#      19
# ---> 20 select_snippet(train_tx, train_target, vct)
#
# <ipython-input-104-981bda444308> in select_snippet(text, target, vct, n)
#      15     for doc in sents:
#      16         doc_bow= vct.transform(doc)
# ---> 17         picked = sents[pick_max_feat(doc_bow, None)]
#      18         print picked
#      19
#
# <ipython-input-104-981bda444308> in pick_max_feat(doc_sents, clf)
#       1 def pick_max_feat(doc_sents, clf):
#       2     print doc_sents.shape
# ----> 3     max_vals = np.argmax(doc_sents, axis=1)[::-1]
#       4     return max_vals[0]
#       5
#
# C:\Python27\lib\site-packages\numpy\core\fromnumeric.pyc in argmax(a, axis)
#     940         argmax = a.argmax
#     941     except AttributeError:
# --> 942         return _wrapit(a, 'argmax', axis)
#     943     return argmax(axis)
#     944
#
# C:\Python27\lib\site-packages\numpy\core\fromnumeric.pyc in _wrapit(obj, method, *args, **kwds)
#      43     except AttributeError:
#      44         wrap = None
# ---> 45     result = getattr(asarray(obj), method)(*args, **kwds)
#      46     if wrap:
#      47         if not isinstance(result, mu.ndarray):
#
# ValueError: axis(=1) out of bounds
# (16, 267154)

# %%
b = [np.sum(x.todense()) for x in train_bow]
print len(b)
print np.min(b), np.max(b)
# Out:
# 250
# 72 1410

# %% [markdown]
# # Statistical Significance of the Results
#
# Compare the three methods among each other to determine if the differences are significant

# %%
## Statistical significance
# Paired t-test
from scipy import stats
print "True vs. rest"
# print "t-statistic: %f, p-value: %f" % stats.ttest_ind(y_true, y_f1)
print "t-statistic: %f, p-value: %f" % stats.ttest_rel(y_true, y_sr)
print "t-statistic: %f, p-value: %f" % stats.ttest_rel(y_true, y_f1)


print "SR vs. rest"
# print "t-statistic: %f, p-value: %f" % stats.ttest_ind(y_sr, y_f1)
print "t-statistic: %f, p-value: %s" % stats.ttest_rel(y_sr, y_true)
print "t-statistic: %f, p-value: %s" % stats.ttest_rel(y_sr, y_f1)


print "F1 vs. rest"
# print "t-statistic: %f, p-value: %f" % stats.ttest_ind(y_f1, y_sr)
print "t-statistic: %f, p-value: %s" % stats.ttest_rel(y_f1, y_true)
print "t-statistic: %f, p-value: %s" % stats.ttest_rel(y_f1, y_sr)
# Out:
# True vs. rest
# t-statistic: 0.643001, p-value: 0.520960
# t-statistic: -7.033240, p-value: 0.000000
# SR vs. rest
# t-statistic: -0.643001, p-value: 0.520959798326
# t-statistic: -9.046399, p-value: 1.31052951035e-16
# F1 vs. rest
# t-statistic: 7.033240, p-value: 3.13123168426e-11
# t-statistic: 9.046399, p-value: 1.31052951035e-16

# %%
## Statistical significance
# Independent t-test
# This is a two-sided test for the null hypothesis that 2 independent samples have identical average (expected) values. 
# This test assumes that the populations have identical variances

#  If we observe a large p-value, for example larger than 0.05 or 0.1, then we cannot 
#     reject the null hypothesis of identical average scores. If the p-value is smaller 
#     than the threshold, e.g. 1%, 5% or 10%, then we reject the null hypothesis of equal 
#     averages

print "True vs. rest"
# print "t-statistic: %f, p-value: %f" % stats.ttest_ind(y_true, y_f1)
print "SR: t-statistic: %.4f, p-value: %s" % stats.ttest_ind(y_true, y_sr)
print "F1: t-statistic: %.4f, p-value: %s" % stats.ttest_ind(y_true, y_f1)


print "SR vs. rest"
# print "t-statistic: %f, p-value: %f" % stats.ttest_ind(y_sr, y_f1)
print "True: t-statistic: %.4f, p-value: %s" % stats.ttest_ind(y_sr, y_true)
print "SR: t-statistic: %.4f, p-value: %s" % stats.ttest_ind(y_sr, y_f1)


print "F1 vs. rest"
# print "t-statistic: %f, p-value: %f" % stats.ttest_ind(y_f1, y_sr)
print "True: t-statistic: %.4f, p-value: %s" % stats.ttest_ind(y_f1, y_true)
print "SR: t-statistic: %.4f, p-value: %s" % stats.ttest_ind(y_f1, y_sr)
# Out:
# True vs. rest
# t-statistic: -2.658445, p-value: 0.008165
# SR: t-statistic: 0.3998, p-value: 0.689521989285
# F1: t-statistic: -2.6584, p-value: 0.00816517322428
# SR vs. rest
# True: t-statistic: -0.3998, p-value: 0.689521989285
# SR: t-statistic: -4.5255, p-value: 7.9575391325e-06
# F1 vs. rest
# True: t-statistic: 2.6584, p-value: 0.00816517322428
# SR: t-statistic: 4.5255, p-value: 7.9575391325e-06

# %% [markdown]
# ## Oracle Measures
#
# We compute oracle accuracy, neutrality rate, class distribution

# %%
# Oracle Accuracy 
non_neutral = np.array(sr_target) < 2
print "SR: %.3f" % (1. * np.sum(np.array(sr_true)[non_neutral] == np.array(sr_target)[non_neutral])/len(np.array(sr_true)[non_neutral]))
non_neutral = np.array(f1_target) < 2
print "F1: %.3f" % (1. * np.sum(np.array(sr_true)[non_neutral] == np.array(f1_target)[non_neutral])/len(np.array(sr_true)[non_neutral]))
# Out:
# SR: 0.838
# F1: 0.850

# %%
# Oracle neutrality
print "SR: %.3f"% (1. * (np.array(sr_target) == 2).sum()/ len(sr_target))
print "F1: %.3f"% (1. * (np.array(f1_target) == 2).sum()/ len(f1_target))
# Out:
# SR: 0.230
# F1: 0.300

# %%
#Class distribution
from collections import Counter
c = Counter(sr_target)
print "SR class distribution"
print "\tClass 0: %.3f\n\tClass 1: %.3f\n\tNeutral: %.3f" % (1.*c[0]/sum(c.values()),1.*c[1]/sum(c.values()),1.*c[2]/sum(c.values()))

c = Counter(f1_target)
print "F1 class distribution"
print "\tClass 0: %.3f\n\tClass 1: %.3f\n\tNeutral: %.3f" % (1.*c[0]/sum(c.values()),1.*c[1]/sum(c.values()),1.*c[2]/sum(c.values()))

c = Counter(sr_true)
print "True  class distribution"
print "\tClass 0: %.3f\n\tClass 1: %.3f\n\tNeutral: %.3f" % (1.*c[0]/sum(c.values()),1.*c[1]/sum(c.values()),1.*c[2]/sum(c.values()))
# Out:
# SR class distribution
# 	Class 0: 0.445
# 	Class 1: 0.325
# 	Neutral: 0.230
# F1 class distribution
# 	Class 0: 0.370
# 	Class 1: 0.330
# 	Neutral: 0.300
# True  class distribution
# 	Class 0: 0.560
# 	Class 1: 0.440
# 	Neutral: 0.000

# %% [markdown]
# ## Testing Oracle Accuracy on Full Training Set

# %%
train_target= bt_true[:50]
train_target.extend(sr_true)
clf = exputil.get_classifier('lrl1', parameter=1)
clf.fit(train_bow, train_target)
print "True:\t%.4f" % metrics.accuracy_score(imdb.test.target, clf.predict(imdb.test.bow))

train_target= bt_true[:50]
train_target.extend(sr_target)
non_neutral = np.array(train_target) < 2
clf = exputil.get_classifier('lrl1', parameter=1)
clf.fit(train_bow[non_neutral], np.array(train_target)[non_neutral])
print "SR:\t%.4f" % metrics.accuracy_score(imdb.test.target, clf.predict(imdb.test.bow))

train_target= bt_true[:50]
train_target.extend(f1_target)
non_neutral = np.array(train_target) < 2
clf = exputil.get_classifier('lrl1', parameter=1)
clf.fit(train_bow[non_neutral], np.array(train_target)[non_neutral])
print "F1:\t%.4f" % metrics.accuracy_score(imdb.test.target, clf.predict(imdb.test.bow))
# Out:
# True:	0.7142
# SR:	0.6539
# F1:	0.6600

# %%
# Last point in plot
print "Last budget point:", x[-1]
print "True:\t%.4f" %  y_true[-1]
print "SR:\t%.4f" % y_sr[-1]
print "F1:\t%.4f" % y_f1[-1]
# Out:
# Last budget point: 250
# True:	0.7004
# SR:	0.6888
# F1:	0.6783

# %% [markdown]
# # Annotation Time
#
# Annotation time per method on IMDB data

# %%
## Annotation time vs. snippet size
fig = plt.figure(figsize=(8,6))
plt.plot(f1_len, f1_time, 'o', label='f1')
plt.plot(sr_len, sr_time, 'o', label='sr1')

plt.xlabel("Number of Words")
plt.ylabel("Annotation time (secs)")
plt.legend(loc='best')
print "Average F1 snippet size: %s, min=%.3f, max=%.3f" % ( np.mean(f1_len), np.min(f1_len), np.max(f1_len))
print "Average SR snippet size: %s, min=%.3f, max=%.3f" % (np.mean(sr_len), np.min(sr_len), np.max(sr_len))
# Out:
# Average F1 snippet size: 18.8, min=1.000, max=223.000
# Average SR snippet size: 24.93, min=2.000, max=100.000

# %%
# Annotation time Histogram
import brewer2mpl
def plot_time(f1_time, sr_time, name='fig_time.png', labels=['f1','sr']):
    fig = plt.figure(figsize=(8,6))
#     a,b,c = plt.hist(f1_time, bins=20, label=labels[0], alpha=.65)
#     a,b,c = plt.hist(sr_time, bins=20, label=labels[1], alpha=.65)
    colors_n = brewer2mpl.get_map('Paired', 'qualitative', 8).mpl_colors[:2]
    a,b,c = plt.hist([f1_time, sr_time], bins=20, label=labels, alpha=.95, color=colors_n)
    plt.xlabel("Annotation time (secs)")
    plt.ylabel("Number of queries")
    plt.title("N=%s mean=%.2f"%(len(f1_time),np.mean([f1_time, sr_time])))
    plt.legend(loc='best')
    print labels[0].upper() + " Annotation avg. %.3f (+/-%.3f) max=%.3f min=%.3f" % (np.mean(f1_time), np.std(f1_time), np.max(f1_time), np.min(f1_time))
    print labels[1].upper() + " Annotation avg. %.3f (+/-%.3f) max=%.3f min=%.3f" % (np.mean(sr_time),np.std(sr_time), np.max(sr_time), np.min(sr_time))
    plt.savefig(name,bbox_inches="tight", dpi=200, transparent=True)

# %%
plot_time(f1_time, sr_time)
# Out:
# F1 Annotation avg. 7.368 (+/-3.946) max=26.637 min=1.774
# SR Annotation avg. 9.277 (+/-4.326) max=25.327 min=2.116

# %% [markdown]
# ## Annotation Time Significance
#
# Run an unpaired t-test on the annotation time comparing sr and f1 methods.
#
# p-value < 0.05, thus then we reject the null hypothesis, that is the two means are different

# %%
# If we observe a large p-value, for example larger than 0.05 or 0.1, then we 
# cannot reject the null hypothesis of identical average scores. If the p-value 
# is smaller than the threshold, e.g. 1%, 5% or 10%, then we reject the null 
# hypothesis of equal averages

print "t-statistic: %f, p-value: %s" % stats.ttest_ind(sr_time, f1_time)
print "t-statistic: %f, p-value: %s" % stats.ttest_rel(sr_time, f1_time)
# Out:
# t-statistic: 4.598137, p-value: 5.73504502481e-06
# t-statistic: 4.932205, p-value: 1.71206677776e-06

# %% [markdown]
# ## Student Evaluation
#
# * True labels
# * Budget: 550
# * Student does not reach .80 accuracy before 500

# %%
import copy
from scipy.sparse import vstack

def add_instance(mat, to_add):
    test_sent = []
    if to_add.shape[0] == 0:
        return mat
    
    for instance in to_add:
        if isinstance(test_sent, list):
            test_sent = vstack([mat, instance], format='csr')
        else:
            test_sent = vstack([test_sent, instance], format='csr')
    return test_sent


def simple_evaluation(clf_name, x, y_true, train_bow, test)
    xx = copy.copy(x)
    y = copy.copy(y_true)
    
    train_target= bt_true[:50]
    train_target.extend(sr_true)
    clf = get_classifier(clf_name)
#     clf = exputil.get_classifier('lrl1', parameter=1)
    clf.fit(train_bow, train_target)
    print "True:\t%.4f" % metrics.accuracy_score(test.target, clf.predict(test.bow))
    accuracy = []
    train_bow = []
    results = []
    for step in xx: 
        train_x = add_instance(train_bow, train_bow[:step])
        y_train = np.append(train_target, y_true[:step])
        clf.fit(train_x, y_train)
        predicted = clf.predict(test.bow)
        acc = metrics.accuracy_score(test.target, predicted)
        accuracy.append(acc)
        results.append([step, acc])
    return results

results = simple_evaluation('lrl1', range(50, 250), y_true, train_bow, imdb.test)

# %%
mpl.style.use('fivethirtyeight')
plt.plot([r[0] for r in results],[r[1] for r in results], label='true')
plt.xlabel("Number of Queries")
plt.ylabel("Accuracy")
# plt.ylim([.55,.75])
plt.legend(loc='best')
plt.savefig('fig_extend.png',bbox_inches="tight", dpi=200, transparent=True)

# %% [markdown]
# ------------------
# # Study with SR-predicted calibration

# %%
from sklearn import metrics

print "CONFUSION MATRIX"
print "SR"

cm = metrics.confusion_matrix(sr_true, sr_target)
print 1.*cm.sum(0)/cm.sum()
print "\n".join("\t".join([str(r) for r in row]) for row in cm)
print
print "F1"
cm = metrics.confusion_matrix(sr_true, f1_target)
print 1.*cm.sum(0)/cm.sum()
print  "\n".join("\t".join([str(r) for r in row]) for row in cm)
# Out:
# CONFUSION MATRIX
# SR
# [ 0.445  0.325  0.23 ]
# 80	16	16
# 9	49	30
# 0	0	0
#
# F1
# [ 0.37  0.33  0.3 ]
# 67	14	31
# 7	52	29
# 0	0	0

# %% [markdown]
# # Annotation Time per Class - V2
#
# We show the distribution of annotation per class (expert)

# %%
#plot histogram of 3 classes
from scipy.stats import norm
import brewer2mpl
def plot_time_byclass(p1, p2, p3, name='fig_time_class.png', labels=['Neg','Pos', 'Neutral'], title='Performance', xtitle='x-axis'):
    fig = plt.figure(figsize=(8,6))
    
    colors_n = brewer2mpl.get_map('Paired', 'qualitative', 8).mpl_colors[:3]
    
    a,b,c = plt.hist([p1, p2, p3], bins=20,  label=labels, alpha=1., fill=True, color=colors_n)#, histtype='step', normed=1, fill=True)

    
    plt.xlabel(xtitle)
    plt.ylabel("Number of queries")
    plt.title(title)
    plt.legend(loc='best')
    ## Create a secondary y-axis
    ax = plt.axes()
    ax2 = ax.twinx()

    for i, data in enumerate([p1,p2,p3]):
        (mu, sigma) = norm.fit(data)
        y = mpl.mlab.normpdf( b, mu, sigma)
        l = plt.plot(b, y, '--', linewidth=2, label=labels[i], color=colors_n[i])
    plt.grid(False)
    print labels[0].upper() + " Annotation avg. %.3f (+/-%.3f) max=%.3f min=%.3f" % (np.mean(p1), np.std(p1), np.max(p1), np.min(p1))
    print labels[1].upper() + " Annotation avg. %.3f (+/-%.3f) max=%.3f min=%.3f" % (np.mean(p2), np.std(p2), np.max(p2), np.min(p2))
    print labels[2].upper() + " Annotation avg. %.3f (+/-%.3f) max=%.3f min=%.3f" % (np.mean(p3), np.std(p3), np.max(p3), np.min(p3))

    plt.savefig(name,bbox_inches="tight", dpi=200, transparent=True)

# %%
def info_time_byclass(m_time, m_expert, name='time_byclass.png'):
    cl0 = np.array(m_time)[np.array(m_expert) == 0]
    cl1 = np.array(m_time)[np.array(m_expert) == 1]
    cl2 = np.array(m_time)[np.array(m_expert) == 2]
    plot_time_byclass(cl0, cl1, cl2, name=name, title="Annotation time (secs)", xtitle="Annotation time (secs)")

    print"C0 vs. C1, C2"
    print "t-statistic: %f, p-value: %s" % stats.ttest_ind(cl0,cl1)
    print "t-statistic: %f, p-value: %s" % stats.ttest_ind(cl0,cl2)
    print"C1 vs. C0, C2"
    print "t-statistic: %f, p-value: %s" % stats.ttest_ind(cl1,cl0)
    print "t-statistic: %f, p-value: %s" % stats.ttest_ind(cl1,cl2)

# %% [markdown]
# ## Annotation Time per Class - First-1

# %%
info_time_byclass(f1_time, f1_expert, name='f1_time_byclass.pdf')
# Out:
# NEG Annotation avg. 6.611 (+/-3.286) max=15.500 min=1.774
# POS Annotation avg. 6.667 (+/-3.512) max=22.860 min=1.808
# NEUTRAL Annotation avg. 9.072 (+/-4.570) max=26.637 min=3.311
# C0 vs. C1, C2
# t-statistic: -0.096271, p-value: 0.923444660504
# t-statistic: -3.591945, p-value: 0.000461869089872
# C1 vs. C0, C2
# t-statistic: 0.096271, p-value: 0.923444660504
# t-statistic: -3.301567, p-value: 0.00125617113974

# %% [markdown]
# ## Annotation Time per Class - SR

# %%
info_time_byclass(sr_time, sr_expert, name='sr_time_byclass.pdf')
# Out:
# NEG Annotation avg. 9.059 (+/-4.206) max=25.327 min=2.275
# POS Annotation avg. 8.478 (+/-3.938) max=19.267 min=2.116
# NEUTRAL Annotation avg. 10.825 (+/-4.673) max=24.228 min=4.041
# C0 vs. C1, C2
# t-statistic: 0.863916, p-value: 0.388995162551
# t-statistic: -2.208143, p-value: 0.0289475677899
# C1 vs. C0, C2
# t-statistic: -0.863916, p-value: 0.388995162551
# t-statistic: -2.834583, p-value: 0.00546959382901

# %% [markdown]
# # Size of the Snippets per Class

# %%
# Snippet size per method
# Annotation time Histogram
def plot_size(f1, sr, name='fig_size.png', labels=['f1','sr']):
    fig=plt.figure(figsize=(8,6))
#     a,b,c = plt.hist(f1, bins=20, label=labels[0], alpha=.65)
#     a,b,c = plt.hist(sr, bins=20, label=labels[1], alpha=.65)
    colors_n = brewer2mpl.get_map('Paired', 'qualitative', 8).mpl_colors[:2]


    a,b,c = plt.hist([f1, sr], bins=20, label=labels, alpha=.95, color=colors_n)
    plt.xlabel("Snippet size (words)")
    plt.ylabel("Frequency")
    plt.title("N=%s mean=%.2f"%(len(f1),np.mean([f1, sr])))
    plt.legend(loc='best')
    print labels[0].upper() + " Annotation avg. %.3f (+/-%.3f) max=%.3f min=%.3f" % (np.mean(f1), np.std(f1), np.max(f1), np.min(f1))
    print labels[1].upper() + " Annotation avg. %.3f (+/-%.3f) max=%.3f min=%.3f" % (np.mean(sr),np.std(sr), np.max(sr), np.min(sr))
    plt.savefig(name,bbox_inches="tight", dpi=200, transparent=True)

# %%
plot_size(f1_len, sr_len, name='fig_size_all.pdf', labels=['f1', 'sr'])
print "t-statistic: %f, p-value: %s" % stats.ttest_ind(f1_len, sr_len)
# Out:
# F1 Annotation avg. 18.800 (+/-17.909) max=223.000 min=1.000
# SR Annotation avg. 24.930 (+/-15.944) max=100.000 min=2.000
# t-statistic: -3.606305, p-value: 0.000350074718709

# %%
def info_size_byclass(m_time, m_expert, name='snip_byclass.png'):
    cl0 = np.array(m_time)[np.array(m_expert) == 0]
    cl1 = np.array(m_time)[np.array(m_expert) == 1]
    cl2 = np.array(m_time)[np.array(m_expert) == 2]
    
    plot_time_byclass(cl0, cl1, cl2, name=name, title="Snippet Size", xtitle="Snippet size (words)")

    print"C0 vs. C1, C2"
    print "t-statistic: %f, p-value: %s" % stats.ttest_ind(cl0,cl1)
    print "t-statistic: %f, p-value: %s" % stats.ttest_ind(cl0,cl2)
    print"C1 vs. C0, C2"
    print "t-statistic: %f, p-value: %s" % stats.ttest_ind(cl1,cl0)
    print "t-statistic: %f, p-value: %s" % stats.ttest_ind(cl1,cl2)

# %% [markdown]
# ## Snippet Size - First-1

# %%
info_size_byclass(f1_len, f1_expert, name='f1_size_byclass.pdf')
# Out:
# NEG Annotation avg. 15.446 (+/-9.143) max=46.000 min=2.000
# POS Annotation avg. 18.939 (+/-11.664) max=66.000 min=1.000
# NEUTRAL Annotation avg. 22.783 (+/-28.047) max=223.000 min=1.000
# C0 vs. C1, C2
# t-statistic: -1.968256, p-value: 0.0510429277546
# t-statistic: -2.100197, p-value: 0.0376143613644
# C1 vs. C0, C2
# t-statistic: 1.968256, p-value: 0.0510429277546
# t-statistic: -1.012434, p-value: 0.313301983342

# %% [markdown]
# ## Snippet Size - SR-PC

# %%
info_size_byclass(sr_len, sr_expert, name='sr_size_byclass.pdf')
# Out:
# NEG Annotation avg. 24.674 (+/-15.355) max=99.000 min=2.000
# POS Annotation avg. 23.462 (+/-13.663) max=71.000 min=5.000
# NEUTRAL Annotation avg. 27.500 (+/-19.380) max=100.000 min=5.000
# C0 vs. C1, C2
# t-statistic: 0.503509, p-value: 0.615335308778
# t-statistic: -0.917492, p-value: 0.360545536053
# C1 vs. C0, C2
# t-statistic: -0.503509, p-value: 0.615335308778
# t-statistic: -1.275979, p-value: 0.204675198451

# %% [markdown]
# ## Simulated Oracle Evaluation
#
# Using a simulated oracle (with the same parameters as the paper) simulate the evaluation of the

# %%
def eval_simulated(clf_name, snippets, train_bow, train_target, test, oracle):
    x = range(50, len(train_target)+1, 1)
    accuracy = []
    train_y = oracle.predict(snippets)
    train_target.extend(train_y)
    print len(x), x[-1]
    for step in x: 
        target_y = np.array(train_target[:step])
        train_x = train_bow[:step]
        non_neutral = target_y < 2
        clf = exputil.get_classifier(clf_name, parameter=1)
        clf.fit(train_x[non_neutral], target_y[non_neutral])
        predicted = clf.predict(test.bow)
        acc = metrics.accuracy_score(test.target, predicted)
        accuracy.append(acc)
#         print step, acc
    return x, accuracy

# %%
# train_target= bt_true[:50]
# x_sim, sim_sr = eval_simulated(clf, snip_bow, train_bow, train_target, imdb.test, sim_oracle)
sim_oracle = exputil.get_classifier('lrl1', parameter=.3)
sim_oracle.fit(imdb.train.bow, imdb.train.target)
# Out:
# LogisticRegression(C=0.3, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, penalty='l1', random_state=None, tol=0.0001)

# %%
train_target= bt_true[:50]
train_y = oracle.predict(snippets)
train_target.extend(train_y)


sim_oracle = exputil.get_classifier('lrl1', parameter=1)
sim_oracle.fit(imdb.train.bow, imdb.train.target)


snip_text, doc_text = read_text(DATA + "/imdb-rnd-sr-expert1-labels.txt")
snip_bow = vct.transform(snip_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-ac0f33bc8ea2> in <module>()
#       1 train_target= bt_true[:50]
# ----> 2 train_y = oracle.predict(snippets)
#       3 train_target.extend(train_y)
#       4
#       5
#
# NameError: name 'oracle' is not defined

# %%
def evaluate_sim_student(clf, train_bow, bt_target, train_text, oracle, test, train, vct):
    import learner
    # train the student on the go
    sent_tk = nltk.data.load('tokenizers/punkt/english.pickle')

    st = learner.strategy.StructuredLearner(clf)
    st.set_sent_tokenizer(sent_tk)
    st.set_vct(vct)
    st.set_snippet_utility('sr')
    st.set_calibration_method("zscores_pred")
   
    x = range(50, 251, 1)
    accuracy = []
    target_y = []
    rnd = np.random.RandomState(123)
    
    target = []
    target.extend(bt_target)
    
    for step in x: 
        if step == 50:
            ## Boostrap
            target_y = np.array(target[:step])
            train_x = train_bow[:step]
            # there are no neutrals here
            st.fit(train_x, target_y, doc_text=np.array(train_text))
        else:
            target_y = np.array(target[:step])
            train_x = train_bow[:step]

            non_neutral = target_y < 2

            st.fit(train_x[non_neutral], target_y[non_neutral], doc_text=np.array(train_text)[non_neutral])
            
            #Get a random pool for calibration + current document
            test_text = [train_text[step-1]]
            perm = rnd.permutation(len(train.data))
            test_text.extend(train.data[:249])
            
            ## compute the max scoring snippet (with calibration)
            _, snippet_text = st._compute_snippet(test_text)

            # Get the label from the oracle, add to targets
            query = vct.transform([snippet_text[0]])
            ora_target = oracle.predict(query)
            probs = oracle.predict_proba(query)
            unc = 1. - probs.max(1)
            neutral = unc > .4
            ora_target[neutral] = 2

            target.extend(ora_target)                      


            # Evaluate student and save result
            predicted = st.model.predict(test.bow)
            acc = metrics.accuracy_score(test.target, predicted)
            accuracy.append(acc)
    #         print step, acc

    return x, accuracy, target_y

# %%
train_text = bt_text[:50]
train_text= np.append(train_text, sr_text)
train_text = np.array([t.decode('utf-8') for t in train_text])
clf = exputil.get_classifier('lrl1', parameter=1)
x, simsr, simsr_target = evaluate_sim_student(clf, train_bow, bt_true[:50], train_text, sim_oracle, imdb.test, imdb.train, vct)

# %%
# Get SR snippets
doc_text, snip_text = read_text(DATA + "/imdb-rnd-sr-expert1-labels.txt")
snip_bow = vct.transform(snip_text)


#Evaluate simulated
simsr_target= bt_true[:50]

train_y = sim_oracle.predict(snip_bow)
probs = sim_oracle.predict_proba(snip_bow)
unc = 1. - probs.max(1)
neutral = unc > .4
train_y[neutral] = 2
simsr_target.extend(train_y)

# x, sim_sr = evaluate_student(clf,train_bow, simsr_target, imdb.test)
x, sim_sr = evaluate_student(clf,train_bow, simsr_target, imdb.test)
# Out:
# Number of fields: 7
# Number of records: 200

# %%
# Get F1 snippets
doc_text, snip_text = read_text(DATA + "/imdb-rnd-first1-expert2-labels.txt")
snip_bow = vct.transform(snip_text)


#Evaluate simulated
simf1_target= bt_true[:50]
train_y = sim_oracle.predict(snip_bow)
probs = sim_oracle.predict_proba(snip_bow)
unc = 1. - probs.max(1)
neutral = unc > .4
train_y[neutral] = 2  #targets by oracle

#reorder targets based on sequence
new_target = [train_y[f1_index.index(i)] for i in sr_index]
simf1_target.extend(new_target)

x, sim_f1 = evaluate_student(clf,train_bow, simf1_target, imdb.test)
# Out:
# Number of fields: 7
# Number of records: 200

# %%
# Get class distribution (true) along the curve 
distribution = bt_true[:50]
distribution.extend(sr_true)
distribution = np.array(distribution)
## Class 1 will be the minority - it sums the 1's in the array
class_dist = distribution.cumsum()[49:] / range(50,len(distribution)+1)

# %%
def plot_evaluation(x_axis, y_axis, labels, class_dist, name='simulated.png'):
    ## Plot student evaluation with simulated and study
    fig = plt.figure(figsize=(8,6))
    colors_n = brewer2mpl.get_map('Set1', 'qualitative', 8).mpl_colors[:len(x_axis)]

    i = 0
    for x, y, l in zip(x_axis, y_axis, labels):
        plt.plot(x,y,label=l, color=colors_n[i])
        i +=1
   
    plt.ylabel("Accuracy")
    plt.ylim([.55,.75])
    plt.legend(loc='best')
    plt.title("Student Accuracy")

    ## Create a secondary y-axis
    ax = plt.axes()
    ax2 = ax.twinx()
    ax2.plot(x, class_dist, 'k--',label='true-dist')
    # ax2.plot([50,250], [.5,.5], '--',label='50%')
    ax2.set_ylabel('Class Distribution %')
    plt.ylim([0,1]) ## affects 2nd axis

    plt.xlabel("Number of Queries")

    plt.savefig(name,bbox_inches="tight", dpi=200, transparent=True)

# %%
plot_evaluation([x,x,x], [y_f1, y_sr, y_true], ['f1','sr', 'true', 'sim-sr'], class_dist, name='sim_student.pdf')
print "Average distribution %.3f, min=%.3f, max=%.3f" % (class_dist.mean(), class_dist.min(), class_dist.max())
# Out:
# Average distribution 0.455, min=0.429, max=0.500

# %%
plot_evaluation([x,x,x], [sim_f1, sim_sr, y_true], ['f1-sim','sr-sim\'', 'true', 'sr-sim'], class_dist, name='sim_student2.pdf')
print "Average distribution %.3f, min=%.3f, max=%.3f" % (class_dist.mean(), class_dist.min(), class_dist.max())

plot_evaluation([x,range(50,250),x], [sim_f1, simsr, y_true], ['f1-sim','sr-sim', 'true', 'sim-sr'], class_dist, name='sim_student3.pdf')
print "Average distribution %.3f, min=%.3f, max=%.3f" % (class_dist.mean(), class_dist.min(), class_dist.max())
# Out:
# Average distribution 0.455, min=0.429, max=0.500
# Average distribution 0.455, min=0.429, max=0.500

# %%
plot_evaluation([x,x,x], [y_f1, sim_f1, y_true], ['f1','f1-sim', 'true'], class_dist, name='sim_student_f1.pdf')
print "Average distribution %.3f, min=%.3f, max=%.3f" % (class_dist.mean(), class_dist.min(), class_dist.max())
# Out:
# Average distribution 0.455, min=0.429, max=0.500

# %%
plot_evaluation([x,x,x], [y_f1, sim_sr, y_true], ['sr','sr\'', 'true'], class_dist, name='sim_student_srsim.pdf')
print "Average distribution %.3f, min=%.3f, max=%.3f" % (class_dist.mean(), class_dist.min(), class_dist.max())
# Out:
# Average distribution 0.455, min=0.429, max=0.500

# %%
plot_evaluation([x,range(50,250),x], [y_sr, simsr, y_true], ['sr','sr-sim', 'true'], class_dist, name='sim_student_srsim2.pdf')
print "Average distribution %.3f, min=%.3f, max=%.3f" % (class_dist.mean(), class_dist.min(), class_dist.max())
# Out:
# Average distribution 0.455, min=0.429, max=0.500

# %% [markdown]
# ## Comparing Human vs. Simulated Evaluations
#
# Using the user study labels compared to the simulated oracle labels

# %%
# SR vs SIM-SR targets
print "SR vs Sim-SR"
cm = metrics.confusion_matrix(sr_target, simsr_target[50:])
print 1.*cm.sum(0)/cm.sum()
print  "\n".join("\t".join([str(r) for r in row]) for row in cm)


print "Percent"
print  "\n".join("\t".join([str(r) for r in row]) for row in 1.*cm/cm.sum())

print "\nF1 vs Sim-F1"
cm = metrics.confusion_matrix(f1_target, simf1_target[50:])
print 1.*cm.sum(0)/cm.sum()
print  "\n".join("\t".join([str(r) for r in row]) for row in cm)

print "Percent"
print  "\n".join("\t".join([str(r) for r in row]) for row in 1.*cm/cm.sum())
# Out:
# SR vs Sim-SR
# [ 0.37  0.42  0.21]
# 59	13	17
# 6	52	7
# 9	19	18
# Percent
# 0.295	0.065	0.085
# 0.03	0.26	0.035
# 0.045	0.095	0.09
#
# F1 vs Sim-F1
# [ 0.33  0.4   0.27]
# 45	12	17
# 7	44	15
# 14	24	22
# Percent
# 0.225	0.06	0.085
# 0.035	0.22	0.075
# 0.07	0.12	0.11

# %%
# SR vs SIM-SR targets
print "SR vs Sim-SR"
cm = metrics.confusion_matrix(sr_target, simsr_target[50:])
print 1.*cm.sum(0)/cm.sum()
print 1.*cm.sum(1)/cm.sum()

print "\nF1 vs Sim-F1"
cm = metrics.confusion_matrix(f1_target, simf1_target[50:])
print 1.*cm.sum(0)/cm.sum()
print 1.*cm.sum(1)/cm.sum()

# %%
print "=== USER STUDY ==="
print "\nTrue vs. rest"
# print "t-statistic: %f \t %f" % stats.ttest_ind(y_true, y_f1)
print "VS. METHOD\tT-STATISTIC\tP-VALUE"
print "SR: \t %.4f \t %.4f" % stats.ttest_ind(y_true, y_sr)
print "F1: \t %.4f \t %.4f" % stats.ttest_ind(y_true, y_f1)
print "SR-SIM: \t %.4f \t %.4f" % stats.ttest_ind(y_true, sim_sr)
print "F1-SIM: \t %.4f \t %.4f" % stats.ttest_ind(y_true, sim_f1)
print "SR-SIM\': \t %.4f \t %.4f" % stats.ttest_ind(y_true, simsr)

print "\nSR vs. rest"
print "F1: \t %.4f \t %.4f" % stats.ttest_ind(y_sr, y_f1)
print "SR-SIM: \t %.4f \t %.4f" % stats.ttest_ind(y_sr, sim_sr)
print "SR-SIM\': \t %.4f \t %.4f" % stats.ttest_ind(y_sr, simsr)
print "F1-SIM: \t %.4f \t %.4f" % stats.ttest_ind(y_sr, sim_f1)

print "\n=== SIMULATED ==="

print "\nSR-SIM vs. rest"
print "F1-SIM: \t %.4f \t %.4f" % stats.ttest_ind(sim_sr, sim_f1)
print "SR-SIM\': \t %.4f \t %.4f" % stats.ttest_ind(sim_sr, simsr)
print "SR: \t %.4f \t %.4f" % stats.ttest_ind(sim_sr, y_sr)
print "F1: \t %.4f \t %.4f" % stats.ttest_ind(sim_sr, y_f1)

print "\nF1-SIM\'-SR vs. rest"

print "SR-SIM: \t %.4f \t %.4f" % stats.ttest_ind(sim_f1, sim_sr)
print "SR-SIM\': \t %.4f \t %.4f" % stats.ttest_ind(sim_f1, simsr)
print "SR: \t %.4f \t %.4f" % stats.ttest_ind(sim_f1, y_sr)
print "F1: \t %.4f \t %.4f" % stats.ttest_ind(sim_f1, y_f1)
# Out:
# === USER STUDY ===
#
# True vs. rest
# VS. METHOD	T-STATISTIC	P-VALUE
# SR: 	 0.3912 	 0.6958
# F1: 	 -2.6606 	 0.0081
# SR-SIM: 	 4.9112 	 0.0000
# F1-SIM: 	 10.5328 	 0.0000
# SR-SIM': 	 6.2485 	 0.0000
#
# SR vs. rest
# F1: 	 -4.5167 	 0.0000
# SR-SIM: 	 7.2310 	 0.0000
# SR-SIM': 	 10.8339 	 0.0000
# F1-SIM: 	 17.0958 	 0.0000
#
# === SIMULATED ===
#
# SR-SIM vs. rest
# F1-SIM: 	 8.1855 	 0.0000
# SR-SIM': 	 1.5195 	 0.1294
# SR: 	 -7.2310 	 0.0000
# F1: 	 -10.1468 	 0.0000
#
# F1-SIM'-SR vs. rest
# SR-SIM: 	 -8.1855 	 0.0000
# SR-SIM': 	 -8.4230 	 0.0000
# SR: 	 -17.0958 	 0.0000
# F1: 	 -18.1468 	 0.0000

# %% [markdown]
# # Investigate Sentences
#
# Check for every document in the training set of the student:
#
# * first sentence
# * best (sr) sentence
# * longest sentence
# * best (human) sentence

# %%
def test_sentence_inv(train_text, snip_text, first_text, true_y, expert_y, n=1):
    sent_tk = nltk.data.load('tokenizers/punkt/english.pickle')
    sent_text = sent_tk.tokenize_sents(t.decode('latin1') for t in train_text)
    snips = [t.decode('latin1') for t in snip_text]
    docs =[t.decode('latin1') for t in train_text]
    matches = []
    best = []
    i = 0
    for doc, snip, sents, t, e in zip(docs[:n], snips[:n], sent_text[:n], true_y[:n], expert_y[:n]):
        print i
        if snip in sents:
            print "Prueba 1, ok"
        if snip in doc:
            print "Prueba 2, ok"
        sr = sents.index(snip)
        best.append(sr)
        print "%s - %s" % (t,e)
#         print "\nfist-1:", sents[0]
#         print "\nSR:", snip
        lens = [len(s.split()) for s in sents]
        longest = np.argmax(lens)
        print "SR = LO", sr == longest
        
        matches.append([sr ==0, sr == longest])
#         print "\nLongest: (%s) - %s" % (lens[longest], sents[longest])
        print "\nDoc:"
        print doc
        print 
        for j, s in enumerate(sents):
            print "%s - %s" % (j,s)
        
        print "*--"*20
        i +=1
    return matches, best

# %%
doc_text, snip_text = read_text(DATA + "/imdb-rnd-sr-expert1-labels.txt")
# Out:
# Number of fields: 7
# Number of records: 200

# %%
matches, sr_picks = test_sentence_inv(doc_text, snip_text,None, sr_true, sr_expert, n=200)
# Out:
# 0
# Prueba 1, ok
# Prueba 2, ok
# 0.0 - 2.0
# SR = LO False
#
# Doc:
# I have yet to read Shirley Jackson's novel, something of which I've been meaning to do for quite sometime. I am sure it has got to be scarier than this film. I remember jumping once when I watched it the other day, although I cannot recall the scene.   The special effects are great and I watched this on DVD, but I am sure in the theatre it must have been an awesome sight. After the first few special effects are done with I was waiting for a story to develop.  I figured this movie at the least has to be loosely based on the classic novel, so a good story should be there, but it wasn't. I was relegated to staring at the gorgeous Catherine Zeta-Jones character throughout the movie basically because there was nothing much else to watch. Lili Talor was such a suck character. I did not like her one bit, something about whiny people. Also, the guy in this film reminded me of the cartoonish Dudley DoRight with his voice and face. I could not relate to the characters at all. Quigon, ahem Liam Neeson did an admirable job trying to get through this movie with some type of acting.  Half to three quarters of the way I was just dying to go see a campy Friday the 13th or a Scream Queenish film! At least there is some type of entertainment value. If there is no story there at least they fill it up with gory deaths or attractive females. This had nothing.
#
# 0 - I have yet to read Shirley Jackson's novel, something of which I've been meaning to do for quite sometime.
# 1 - I am sure it has got to be scarier than this film.
# 2 - I remember jumping once when I watched it the other day, although I cannot recall the scene.
# 3 - The special effects are great and I watched this on DVD, but I am sure in the theatre it must have been an awesome sight.
# 4 - After the first few special effects are done with I was waiting for a story to develop.
# 5 - I figured this movie at the least has to be loosely based on the classic novel, so a good story should be there, but it wasn't.
# 6 - I was relegated to staring at the gorgeous Catherine Zeta-Jones character throughout the movie basically because there was nothing much else to watch.
# 7 - Lili Talor was such a suck character.
# 8 - I did not like her one bit, something about whiny people.
# 9 - Also, the guy in this film reminded me of the cartoonish Dudley DoRight with his voice and face.
# 10 - I could not relate to the characters at all.
# 11 - Quigon, ahem Liam Neeson did an admirable job trying to get through this movie with some type of acting.
# 12 - Half to three quarters of the way I was just dying to go see a campy Friday the 13th or a Scream Queenish film!
# 13 - At least there is some type of entertainment value.
# 14 - If there is no story there at least they fill it up with gory deaths or attractive females.
# 15 - This had nothing.
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 1
# Prueba 1, ok
# Prueba 2, ok
# 0.0 - 0.0
# SR = LO False
#
# Doc:
# Had I checked IMDb BEFORE renting this DVD from Netflix, I'd have a couple of hours of my life back. I'm frankly suspicious when I see that a film's director also wrote it. In this case, according to the credits, the same guy was "writter and director" - unfortunately, an indication of the overall quality of this production. There were a few interesting moments (e.g., Judy Tenuta's scene reminded of her early comedy routines touting Judy-ism) which led me to rate this two stars rather than one. Those moments, however, were few and far between ... and I almost did not get to see them because the opening sequence was nearly incomprehensible to me, not to mention reprehensible in its violence. I admit I went back to watch that part again to see if I had missed something that would help me figure it out once I'd seen the whole thing. Nope, though I at least recognized who the characters were who would turn out to be important later. The "spinning camera" technique was overused and essentially pointless. I found myself talking to the TV screen: "What?!?" or "For goodness sake, get ON with it!" Not recommended.
#
# 0 - Had I checked IMDb BEFORE renting this DVD from Netflix, I'd have a couple of hours of my life back.
# 1 - I'm frankly suspicious when I see that a film's director also wrote it.
# 2 - In this case, according to the credits, the same guy was "writter and director" - unfortunately, an indication of the overall quality of this production.
# 3 - There were a few interesting moments (e.g., Judy Tenuta's scene reminded of her early comedy routines touting Judy-ism) which led me to rate this two stars rather than one.
# 4 - Those moments, however, were few and far between ... and I almost did not get to see them because the opening sequence was nearly incomprehensible to me, not to mention reprehensible in its violence.
# 5 - I admit I went back to watch that part again to see if I had missed something that would help me figure it out once I'd seen the whole thing.
# 6 - Nope, though I at least recognized who the characters were who would turn out to be important later.
# 7 - The "spinning camera" technique was overused and essentially pointless.
# 8 - I found myself talking to the TV screen: "What?!?"
# 9 - or "For goodness sake, get ON with it!"
# 10 - Not recommended.
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 2
# Prueba 1, ok
# Prueba 2, ok
# 0.0 - 0.0
# SR = LO True
#
# Doc:
# " It had to be You" is another sign that Hollywood is running out of ideas. This picture is about Charlie Hudson a former police officer turned Author. When Charlie's fiancÃ© goes out of town he's stuck with all of the wedding planning. He spends a week at a fancy hotel and meets Anna Penn a teacher who just happens to also be getting married. The two quickly become friends and set out to plan their separate weddings together. This is when the plot gets boring, Charlie falls in love with Anna and she has to choose between a safe life or Charlie. This movie rips off every romantic comedy ever made and just has you waiting for the end of the movie so you can do something else. Micahel Vartan and Natasha Henstridge give really mediocre performances which just makes this movie all the more gut wrenching to watch.
#
# 0 - " It had to be You" is another sign that Hollywood is running out of ideas.
# 1 - This picture is about Charlie Hudson a former police officer turned Author.
# 2 - When Charlie's fiancÃ© goes out of town he's stuck with all of the wedding planning.
# 3 - He spends a week at a fancy hotel and meets Anna Penn a teacher who just happens to also be getting married.
# 4 - The two quickly become friends and set out to plan their separate weddings together.
# 5 - This is when the plot gets boring, Charlie falls in love with Anna and she has to choose between a safe life or Charlie.
# 6 - This movie rips off every romantic comedy ever made and just has you waiting for the end of the movie so you can do something else.
# 7 - Micahel Vartan and Natasha Henstridge give really mediocre performances which just makes this movie all the more gut wrenching to watch.
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 3
# Prueba 1, ok
# Prueba 2, ok
# 1.0 - 1.0
# SR = LO False
#
# Doc:
# What's inexplicable? Firstly, the hatred towards this movie. It may not be the greatest movie of all time, but gimme a break, it got 11 oscars for a reason, it made EIGHTEEN HUNDRED MILLION DOLLARS for a reason. It's a damn good movie. Which brings to the other inexplicable aspect of it. I have no idea whatsoever why this movie left such an impression on me when I saw it in theaters. I've rewatched it on TV and video, and it had none of the impact it had when I saw it on the big screen (twice, or maybe three times, actually). But that might be it, the appeal of it. It's a Movie, yes, capital M there, it's an Epic, it's a spectacle in the order of Gone With the Wind or Ben Hur. Now, Ben Hur and Gone With the Wind seem kinda hokey to me, with the hammy acting and excessive melodrama. Not that Titanic has none of that. Well, the acting was actually very good. The melodrama was quite heavy-handed at times.  But the reason Titanic works is that it's such an emotional ride. I usually enjoy movies that stimulate the mind, or give me a visual thrill. This movie isn't exactly dumb, but it's not cerebral at all. The visual thrills are simply means to an end, to fuel the emotions of the audience. I didn't cry when Bambi's mom died, I don't react to tearjerkers. But this is a tearjerker to the power of ten million, an emotional rollercoaster that, if it were a regular one, would make Buzz Aldrin scream like a little girl. And I'm sure that if you see it on video and have decided that you hate it, and have a ready supply of cynicism, then you can thoroughly dislike this movie. But if you let that disbelief suspend just a bit, if you give this epic melodrama the benefit of the doubt, you'll enjoy it completely. And look at the top ten grossing films of all time. Is a single one of them bad? Is a single one of them worth a score of 1 out of 10? No, not even The Phantom Menace. And this movie made 1.8 BILLION DOLLARS worldwide. It can't be bad. Not possible. 10/10.  p.s. how can anyone even consider comparing this to spiderman? spiderman was a fun movie, but it was a total 9/11 kneejerk that caused it to gross as much as it did. it simply wasn't anything all that special. no one will remember it in 50 years. but i'm pretty sure Titanic will be remembered.
#
# 0 - What's inexplicable?
# 1 - Firstly, the hatred towards this movie.
# 2 - It may not be the greatest movie of all time, but gimme a break, it got 11 oscars for a reason, it made EIGHTEEN HUNDRED MILLION DOLLARS for a reason.
# 3 - It's a damn good movie.
# 4 - Which brings to the other inexplicable aspect of it.
# 5 - I have no idea whatsoever why this movie left such an impression on me when I saw it in theaters.
# 6 - I've rewatched it on TV and video, and it had none of the impact it had when I saw it on the big screen (twice, or maybe three times, actually).
# 7 - But that might be it, the appeal of it.
# 8 - It's a Movie, yes, capital M there, it's an Epic, it's a spectacle in the order of Gone With the Wind or Ben Hur.
# 9 - Now, Ben Hur and Gone With the Wind seem kinda hokey to me, with the hammy acting and excessive melodrama.
# 10 - Not that Titanic has none of that.
# 11 - Well, the acting was actually very good.
# 12 - The melodrama was quite heavy-handed at times.
# 13 - But the reason Titanic works is that it's such an emotional ride.
# 14 - I usually enjoy movies that stimulate the mind, or give me a visual thrill.
# 15 - This movie isn't exactly dumb, but it's not cerebral at all.
# 16 - The visual thrills are simply means to an end, to fuel the emotions of the audience.
# 17 - I didn't cry when Bambi's mom died, I don't react to tearjerkers.
# 18 - But this is a tearjerker to the power of ten million, an emotional rollercoaster that, if it were a regular one, would make Buzz Aldrin scream like a little girl.
# 19 - And I'm sure that if you see it on video and have decided that you hate it, and have a ready supply of cynicism, then you can thoroughly dislike this movie.
# 20 - But if you let that disbelief suspend just a bit, if you give this epic melodrama the benefit of the doubt, you'll enjoy it completely.
# 21 - And look at the top ten grossing films of all time.
# 22 - Is a single one of them bad?
# 23 - Is a single one of them worth a score of 1 out of 10?
# 24 - No, not even The Phantom Menace.
# 25 - And this movie made 1.8 BILLION DOLLARS worldwide.
# 26 - It can't be bad.
# 27 - Not possible.
# 28 - 10/10.
# 29 - p.s.
# 30 - how can anyone even consider comparing this to spiderman?
# 31 - spiderman was a fun movie, but it was a total 9/11 kneejerk that caused it to gross as much as it did.
# 32 - it simply wasn't anything all that special.
# 33 - no one will remember it in 50 years.
# 34 - but i'm pretty sure Titanic will be remembered.
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 4
# Prueba 1, ok
# Prueba 2, ok
# 0.0 - 0.0
# SR = LO False
#
# Doc:
# Impenetrable rubbish. This has to be one of the worst movies I have ever seen. The dialogue is ghastly, the horror effects are laughable. The only thing that kept me watching was the ever-splendid and totally underrated Michael Cule.
#
# 0 - Impenetrable rubbish.
# 1 - This has to be one of the worst movies I have ever seen.
# 2 - The dialogue is ghastly, the horror effects are laughable.
# 3 - The only thing that kept me watching was the ever-splendid and totally underrated Michael Cule.
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 5
# Prueba 1, ok
# Prueba 2, ok
# 0.0 - 0.0
# SR = LO False
#
# Doc:
# With a story and screenplay that seems to have been written by a high schooler, 'The Art of Seduction' fails to deliver the romantic, sophisticated experience it tries to bill itself as. The two main characters have the potential to be interesting - both male and female lead are "swinging singles (or in the female lead's case, engaged)", but 'The Art of Seduction' doesn't even try. Shirking from a frank examination of these two characters' personalities, 'The Art of Seduction' eschews anything of substance for a basis of thin, lean stereotype.   'The Art of Seduction' is insulting - insulting to its characters, insulting to men and women, and insulting to its audiences' expectations. It takes the awful beautiful people we all know and plays out their painful interactions while expecting us to idolize them. Ji-wan is an immature, spoiled, manipulative bitch. The viewer is expected to like and forgive her flaws because she's pretty. Min-jun, well, he's exactly the same. Neither are nice people. The "humour" in this film primarily revolve around Ji-wan and Min-jun's outlandish attempts at outdoing each other in the honourable art of lying and manipulation. No character development occurs, and we never learn why Ji-wan and Min-jun are like this. We are simply expected to take them as they are, and not ask questions - they're cute!, and that's all that matters. The copious references to the celebrity of the main actors in azn cinema scenester's reviews may tip you off to 'Art of Seduction's shallowness.   If you're still in high school, you liked Grease, or you are a yellow fever victim, you may like this movie.  Despite its "Romance" tag, this is not a very good date movie.
#
# 0 - With a story and screenplay that seems to have been written by a high schooler, 'The Art of Seduction' fails to deliver the romantic, sophisticated experience it tries to bill itself as.
# 1 - The two main characters have the potential to be interesting - both male and female lead are "swinging singles (or in the female lead's case, engaged)", but 'The Art of Seduction' doesn't even try.
# 2 - Shirking from a frank examination of these two characters' personalities, 'The Art of Seduction' eschews anything of substance for a basis of thin, lean stereotype.
# 3 - 'The Art of Seduction' is insulting - insulting to its characters, insulting to men and women, and insulting to its audiences' expectations.
# 4 - It takes the awful beautiful people we all know and plays out their painful interactions while expecting us to idolize them.
# 5 - Ji-wan is an immature, spoiled, manipulative bitch.
# 6 - The viewer is expected to like and forgive her flaws because she's pretty.
# 7 - Min-jun, well, he's exactly the same.
# 8 - Neither are nice people.
# 9 - The "humour" in this film primarily revolve around Ji-wan and Min-jun's outlandish attempts at outdoing each other in the honourable art of lying and manipulation.
# 10 - No character development occurs, and we never learn why Ji-wan and Min-jun are like this.
# 11 - We are simply expected to take them as they are, and not ask questions - they're cute!, and that's all that matters.
# 12 - The copious references to the celebrity of the main actors in azn cinema scenester's reviews may tip you off to 'Art of Seduction's shallowness.
# 13 - If you're still in high school, you liked Grease, or you are a yellow fever victim, you may like this movie.
# 14 - Despite its "Romance" tag, this is not a very good date movie.
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 6
# Prueba 1, ok
# Prueba 2, ok
# 0.0 - 0.0
# SR = LO False
#
# Doc:
# You know this is gonna be a cheesy movie when:  1. It was made it the 50's 2. It's in black and white. 3. It has no name actors! 4. Screaming makes up for the lack of special effects!  Well not to be outdone - this movie brilliantly incorporated all four of the above elements to turn this into a true cinematic blunder.  Okay - shhhhh but I am gonna discuss special effects here - or lack of them -   Did you catch the underwater scenes? It looks like it was poorly filmed through an aquarium - note the cape flapping in the breeze.  And the repeated re-use of Stock Footage, (exterior house shots, the bridges scenes -- great enhanced the K-R-A-F-Tiness of this film - not since "PLAN 9" - have I seen such creative usage of stock footage.  And hey where there was a lack of special effects - not to worry - screaming DOES take the place of special effects in this movie as well. Yes this movie even cleverly used that old hack trick.  Grab the popcorn - set your brain on stun (several fermented beverages DEFINITELY helps), sit back, and wonder: why the heck did they put this on film again?  Wayno
#
# 0 - You know this is gonna be a cheesy movie when:  1.
# 1 - It was made it the 50's 2.
# 2 - It's in black and white.
# 3 - 3.
# 4 - It has no name actors!
# 5 - 4.
# 6 - Screaming makes up for the lack of special effects!
# 7 - Well not to be outdone - this movie brilliantly incorporated all four of the above elements to turn this into a true cinematic blunder.
# 8 - Okay - shhhhh but I am gonna discuss special effects here - or lack of them -   Did you catch the underwater scenes?
# 9 - It looks like it was poorly filmed through an aquarium - note the cape flapping in the breeze.
# 10 - And the repeated re-use of Stock Footage, (exterior house shots, the bridges scenes -- great enhanced the K-R-A-F-Tiness of this film - not since "PLAN 9" - have I seen such creative usage of stock footage.
# 11 - And hey where there was a lack of special effects - not to worry - screaming DOES take the place of special effects in this movie as well.
# 12 - Yes this movie even cleverly used that old hack trick.
# 13 - Grab the popcorn - set your brain on stun (several fermented beverages DEFINITELY helps), sit back, and wonder: why the heck did they put this on film again?
# 14 - Wayno
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 7
# Prueba 1, ok
# Prueba 2, ok
# 0.0 - 0.0
# SR = LO False
#
# Doc:
# Six for the price of one! So it is a bonanza time for Cinegoers. Isn't it? Here it is not one, not two but all SIX-love stories, an ensemble cast of top stars of bollywood, plus all stories in the genre of your favorite top directors Johar, Bhansali, Chopra et al. You will get to see every damn type of love story that you enjoyed or rather tolerated for years now. So no big deal for you. Do you need anything more than this? No sir, thank you. Why sir? Enough is enough. Please spare us. They signed every top star that they manage to sign, whether required or not, so they end up making a circus of stars, believe it or not. Too crowded Every thing depicted here is exactly how it is prescribed in bollywood textbook of romances. Plus you have to justify the length given to each story, as each has stars. Therefore, it is too long-three hours plus. The gags are filmy. Characters are filmy. Problems, Barriers, situations, resolution Â yes you guessed it right, againÂ. filmy-tried and tested. Same hundreds of dancers dancing in colorful costumes in background. Why they have no other work to do? All couples are sugary-sweet, fairy tale type, Picture perfect. All are good looking. Each story beginning in a perfect way and therefore should ends also in that impossible perfect manner? Too haphazard. You can't connect to a single story. Here you have everything that you already seen a million times. Bloody fake, unreal, escapist abnormal stories considered normal for more than hundred years since evolution of this Indian cinema. What a mockery of sensibilities of today's audience? Yes it could have worked as a parody if he just paid tribute to love-stories of yesteryear but alas even that thing is not explored. At least, Director Nikhil Advani should have attempted one unconventional, offbeat love story but then what will happen to the tradition of living up to the mark of commercial bollwood potboiler brigade? Oh! Somebody has to carry on, no. Imagine on one hand audience finds it difficult to sit through one such love story and here we have six times the pain. I mean six damn stories. I mean double the fun of chopra's Mohabbatein (Year 2000) In this age and time, get something real, guys. We are now desperate to see some not so colorful people and not so bright stories Oh, What have you said just now- come on, that is entertainment. My advice, please don't waste your time henceforth reading such reviews. Go instead, have some more such entertainment! Thank you.
#
# 0 - Six for the price of one!
# 1 - So it is a bonanza time for Cinegoers.
# 2 - Isn't it?
# 3 - Here it is not one, not two but all SIX-love stories, an ensemble cast of top stars of bollywood, plus all stories in the genre of your favorite top directors Johar, Bhansali, Chopra et al.
# 4 - You will get to see every damn type of love story that you enjoyed or rather tolerated for years now.
# 5 - So no big deal for you.
# 6 - Do you need anything more than this?
# 7 - No sir, thank you.
# 8 - Why sir?
# 9 - Enough is enough.
# 10 - Please spare us.
# 11 - They signed every top star that they manage to sign, whether required or not, so they end up making a circus of stars, believe it or not.
# 12 - Too crowded Every thing depicted here is exactly how it is prescribed in bollywood textbook of romances.
# 13 - Plus you have to justify the length given to each story, as each has stars.
# 14 - Therefore, it is too long-three hours plus.
# 15 - The gags are filmy.
# 16 - Characters are filmy.
# 17 - Problems, Barriers, situations, resolution Â yes you guessed it right, againÂ.
# 18 - filmy-tried and tested.
# 19 - Same hundreds of dancers dancing in colorful costumes in background.
# 20 - Why they have no other work to do?
# 21 - All couples are sugary-sweet, fairy tale type, Picture perfect.
# 22 - All are good looking.
# 23 - Each story beginning in a perfect way and therefore should ends also in that impossible perfect manner?
# 24 - Too haphazard.
# 25 - You can't connect to a single story.
# 26 - Here you have everything that you already seen a million times.
# 27 - Bloody fake, unreal, escapist abnormal stories considered normal for more than hundred years since evolution of this Indian cinema.
# 28 - What a mockery of sensibilities of today's audience?
# 29 - Yes it could have worked as a parody if he just paid tribute to love-stories of yesteryear but alas even that thing is not explored.
# 30 - At least, Director Nikhil Advani should have attempted one unconventional, offbeat love story but then what will happen to the tradition of living up to the mark of commercial bollwood potboiler brigade?
# 31 - Oh!
# 32 - Somebody has to carry on, no.
# 33 - Imagine on one hand audience finds it difficult to sit through one such love story and here we have six times the pain.
# 34 - I mean six damn stories.
# 35 - I mean double the fun of chopra's Mohabbatein (Year 2000) In this age and time, get something real, guys.
# 36 - We are now desperate to see some not so colorful people and not so bright stories Oh, What have you said just now- come on, that is entertainment.
# 37 - My advice, please don't waste your time henceforth reading such reviews.
# 38 - Go instead, have some more such entertainment!
# 39 - Thank you.
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 8
# Prueba 1, ok
# Prueba 2, ok
# 1.0 - 2.0
# SR = LO True
#
# Doc:
# Our Song is a marvelous example of passionate, movie making at its aesthetic best. It is, in fact, a genuine wonder of a movie; a penetrating and insightful work of art that chronicles the lives of three young inner city (Crown Heights, Brooklyn) girls during a particular summer in their lives when the perplexities of their approaching adulthood will compel each of them to make a number of difficult, life altering choices that will likely re-define who each of them is, as well as how they will continue to relate to one another in years to come.  Jim McKay's writing/direction is graceful and uncluttered. There is no sappy, gratuitous sentimentality nor are there clichÃ© ridden solutions in this film. What we see here seems, at times, to be heart breakingly real. There is a naturalism - a credibility, if you will - in Our Song that surpasses that of other giants in this genre, including American Graffiti and Cooley High.  Much of the credit for the film's spirit goes to its principle actors. The combined presence of Melisa Martinez (Maria), Kerry Washington (Lanisha), and Anna Simpson (Joycelyn) is dazzlingly powerful. It would be easy - and, of course, blatantly obtuse - to dismiss, as some apparently have, the performances of these three as apathetic or unemotional. In fact, their quiet charm, their instinctive sense of dignity and their raw, sometimes unconventional intelligence, throughout the film, are absolutely riveting. One would have to be completely "out of touch" with, or completely indifferent to, the behavior of teenagers to miss the resounding authenticity in what these three young ladies bring to the screen. Likewise, the supporting cast, particularly Marlene Forte as Lanisha's mother, compliments the work of the three girls as well as the overall tone of the film.  Our Song is a film not to be missed - by anyone of any age.
#
# 0 - Our Song is a marvelous example of passionate, movie making at its aesthetic best.
# 1 - It is, in fact, a genuine wonder of a movie; a penetrating and insightful work of art that chronicles the lives of three young inner city (Crown Heights, Brooklyn) girls during a particular summer in their lives when the perplexities of their approaching adulthood will compel each of them to make a number of difficult, life altering choices that will likely re-define who each of them is, as well as how they will continue to relate to one another in years to come.
# 2 - Jim McKay's writing/direction is graceful and uncluttered.
# 3 - There is no sappy, gratuitous sentimentality nor are there clichÃ© ridden solutions in this film.
# 4 - What we see here seems, at times, to be heart breakingly real.
# 5 - There is a naturalism - a credibility, if you will - in Our Song that surpasses that of other giants in this genre, including American Graffiti and Cooley High.
# 6 - Much of the credit for the film's spirit goes to its principle actors.
# 7 - The combined presence of Melisa Martinez (Maria), Kerry Washington (Lanisha), and Anna Simpson (Joycelyn) is dazzlingly powerful.
# 8 - It would be easy - and, of course, blatantly obtuse - to dismiss, as some apparently have, the performances of these three as apathetic or unemotional.
# 9 - In fact, their quiet charm, their instinctive sense of dignity and their raw, sometimes unconventional intelligence, throughout the film, are absolutely riveting.
# 10 - One would have to be completely "out of touch" with, or completely indifferent to, the behavior of teenagers to miss the resounding authenticity in what these three young ladies bring to the screen.
# 11 - Likewise, the supporting cast, particularly Marlene Forte as Lanisha's mother, compliments the work of the three girls as well as the overall tone of the film.
# 12 - Our Song is a film not to be missed - by anyone of any age.
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 9
# Prueba 1, ok
# Prueba 2, ok
# 1.0 - 1.0
# SR = LO False
#
# Doc:
# To quote Flik, that was my reaction exactly: Wow...you're perfect! This is the best movie! I think I can even say it's become my favorite movie ever, even. Wow. I tell you what, wow.
#
# 0 - To quote Flik, that was my reaction exactly: Wow...you're perfect!
# 1 - This is the best movie!
# 2 - I think I can even say it's become my favorite movie ever, even.
# 3 - Wow.
# 4 - I tell you what, wow.
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 10
# Prueba 1, ok
# Prueba 2, ok
# 1.0 - 2.0
# SR = LO False
#
# Doc:
# It started out slow after an excellent animated intro, as the director had a bunch of characters and school setting to develop. Once the bet is on, though, the movie picks up the pace as it's a race against time to see if a certain number of worms can be eaten by 7 pm. We had a good opportunity on the way home to discuss some things with our son: bullies, helping others, mind over matter when you don't want to do something.  Of special note is the girl who played Erica (Erk): Hallie Kate Eisenberg. The director kinda sneaks her in unexpectedly, and when she is on-screen she is captivating. She's one of those "Hey, she looks familiar" faces, and then I remembered that she was the little girl that Pepsi featured about 8 years ago. She was also in "Paulie", that movie about the parrot who tries to find his way home.  Ms. Eisenberg made many TV and movie appearances in '99-00, but then was not seen much for the next few years. She's now 14 and is growing up to be a beautiful woman. Her smile really warms up the screen. If she can get some more good roles she could have as good a career (or better?) than Haley Joel Osment, another three named kid actor, but hopefully without some of the problems that Osment has been in lately.  Anywhozitz, according to my 8 y.o. son, who just finished reading the story, the film did not seem to follow the book all that well, but was entertaining none the less. The ending of the film seemed like a big setup for some sequels (How to Eat Boiled Slugs? Escargot Kid's Style?), which might not be such a bad thing. It was nice to take the family to a movie and not have to worry about language, violence or sex scenes.  One other good aspect of the movie was the respect/fear engendered by the principal Mr. Burdock (Boilerplate). Movies nowadays tend to show adult authority figures as buffoons. While he has one particular goofy scene, he ruled the school with a firm hand. It was also nice to see Andrea Martin getting some work.
#
# 0 - It started out slow after an excellent animated intro, as the director had a bunch of characters and school setting to develop.
# 1 - Once the bet is on, though, the movie picks up the pace as it's a race against time to see if a certain number of worms can be eaten by 7 pm.
# 2 - We had a good opportunity on the way home to discuss some things with our son: bullies, helping others, mind over matter when you don't want to do something.
# 3 - Of special note is the girl who played Erica (Erk): Hallie Kate Eisenberg.
# 4 - The director kinda sneaks her in unexpectedly, and when she is on-screen she is captivating.
# 5 - She's one of those "Hey, she looks familiar" faces, and then I remembered that she was the little girl that Pepsi featured about 8 years ago.
# 6 - She was also in "Paulie", that movie about the parrot who tries to find his way home.
# 7 - Ms. Eisenberg made many TV and movie appearances in '99-00, but then was not seen much for the next few years.
# 8 - She's now 14 and is growing up to be a beautiful woman.
# 9 - Her smile really warms up the screen.
# 10 - If she can get some more good roles she could have as good a career (or better?)
# 11 - than Haley Joel Osment, another three named kid actor, but hopefully without some of the problems that Osment has been in lately.
# 12 - Anywhozitz, according to my 8 y.o.
# 13 - son, who just finished reading the story, the film did not seem to follow the book all that well, but was entertaining none the less.
# 14 - The ending of the film seemed like a big setup for some sequels (How to Eat Boiled Slugs?
# 15 - Escargot Kid's Style?
# 16 - ), which might not be such a bad thing.
# 17 - It was nice to take the family to a movie and not have to worry about language, violence or sex scenes.
# 18 - One other good aspect of the movie was the respect/fear engendered by the principal Mr. Burdock (Boilerplate).
# 19 - Movies nowadays tend to show adult authority figures as buffoons.
# 20 - While he has one particular goofy scene, he ruled the school with a firm hand.
# 21 - It was also nice to see Andrea Martin getting some work.
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 11
# Prueba 1, ok
# Prueba 2, ok
# 0.0 - 1.0
# SR = LO False
#
# Doc:
# Swayze doesn't make a very convincing Alan Quatermain. Compared to Stewart Granger; which growing up was my ultimate hero in films like the 1952 "Scaramouche", the 1952 "Prisoner of Zenda" and the 1950 "King Solomon's Mines"; Patrick Swayze fails utterly. Even the portrayal of an older Alan Quatermain by Sean Connery in "League of Extraordinary Gentlemen" was very good in an otherwise big flop. Also Alison Doody lacks the grace of Deborah Kerr in the role of the leading lady, and last but not least the impressive Siriaque in the role of Umbopa makes it very hard for anyone to fill his (shoes)!!! For someone who was disappointed by Richard Chamberlain's 1985 version, I now highly recommend it if you can't get your hand on the granger version.
#
# 0 - Swayze doesn't make a very convincing Alan Quatermain.
# 1 - Compared to Stewart Granger; which growing up was my ultimate hero in films like the 1952 "Scaramouche", the 1952 "Prisoner of Zenda" and the 1950 "King Solomon's Mines"; Patrick Swayze fails utterly.
# 2 - Even the portrayal of an older Alan Quatermain by Sean Connery in "League of Extraordinary Gentlemen" was very good in an otherwise big flop.
# 3 - Also Alison Doody lacks the grace of Deborah Kerr in the role of the leading lady, and last but not least the impressive Siriaque in the role of Umbopa makes it very hard for anyone to fill his (shoes)!!!
# 4 - For someone who was disappointed by Richard Chamberlain's 1985 version, I now highly recommend it if you can't get your hand on the granger version.
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 12
# Prueba 1, ok
# Prueba 2, ok
# 0.0 - 0.0
# SR = LO False
#
# Doc:
# This film was a waste of time, even rented on DVD. If super-speedy camera shots get any faster than this, we might as well pay twenty bucks to get in the laundromat, get popcorn, and watch the dryer spin. Jet Li is so much better than this. One can only hope that he won't be making deals anytime soon to make another cliche-ridden film like The One.  If there's one film you should avoid, this is "The One".
#
# 0 - This film was a waste of time, even rented on DVD.
# 1 - If super-speedy camera shots get any faster than this, we might as well pay twenty bucks to get in the laundromat, get popcorn, and watch the dryer spin.
# 2 - Jet Li is so much better than this.
# 3 - One can only hope that he won't be making deals anytime soon to make another cliche-ridden film like The One.
# 4 - If there's one film you should avoid, this is "The One".
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 13
# Prueba 1, ok
# Prueba 2, ok
# 0.0 - 2.0
# SR = LO True
#
# Doc:
# Actress Ruth Roman's real-life philanthropic gesture to help entertain troops arriving from and leaving for the Korean War at an air base near San Francisco jump-started this all-star Warner Bros. salute to patriotism and song. Many celebrities make guest appearances while a love-hate romance develops between a budding starlet and a painfully green and skinny Air Force Corporal (Ron Hagerthy, who looks like he should be delivering newspapers from his bicycle). Seems the Corporal has fooled the actress into thinking he's off to battle when actually he's part of a airplane carrier crew, flying to and from Honolulu (you'd think she'd be happy he was staying out of harm's way, but instead she acts just like most childish females in 1950s movies). Doris Day is around for the first thirty minutes or so, and her distinct laugh and plucky song numbers are most pleasant. Roman is also here, looking glamorous, while James Cagney pokes fun at his screen persona and Gordon MacRae sings in his handsome baritone. Jane Wyman sings, too, in a hospital bedside reprise following Doris Day's lead, causing one to wonder, "Did they run out of sets?" For undemanding viewers, an interesting flashback to another time and place. Still, the low-rent production and just-adequate technical aspects render "Starlift" strictly a second-biller. *1/2 from ****
#
# 0 - Actress Ruth Roman's real-life philanthropic gesture to help entertain troops arriving from and leaving for the Korean War at an air base near San Francisco jump-started this all-star Warner Bros. salute to patriotism and song.
# 1 - Many celebrities make guest appearances while a love-hate romance develops between a budding starlet and a painfully green and skinny Air Force Corporal (Ron Hagerthy, who looks like he should be delivering newspapers from his bicycle).
# 2 - Seems the Corporal has fooled the actress into thinking he's off to battle when actually he's part of a airplane carrier crew, flying to and from Honolulu (you'd think she'd be happy he was staying out of harm's way, but instead she acts just like most childish females in 1950s movies).
# 3 - Doris Day is around for the first thirty minutes or so, and her distinct laugh and plucky song numbers are most pleasant.
# 4 - Roman is also here, looking glamorous, while James Cagney pokes fun at his screen persona and Gordon MacRae sings in his handsome baritone.
# 5 - Jane Wyman sings, too, in a hospital bedside reprise following Doris Day's lead, causing one to wonder, "Did they run out of sets?"
# 6 - For undemanding viewers, an interesting flashback to another time and place.
# 7 - Still, the low-rent production and just-adequate technical aspects render "Starlift" strictly a second-biller.
# 8 - *1/2 from ****
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 14
# Prueba 1, ok
# Prueba 2, ok
# 1.0 - 1.0
# SR = LO False
#
# Doc:
# I used to watch this show when I was a little girl. Although I don't remember much about it, I must say that it was a pretty good show. Also, I don't think I've seen every episode. However, if you ask me, it was still a good show. I vaguely remember the theme song. Everyone was ideally cast, the costume design was great. The performances were top-grade, too. I just hope some network brings this series back one day so that I'll be able to see every episode. Before I wrap this up, I'd like to say that I'll always remember this show in my memory forever, even though I don't think I've seen every episode. Now, in conclusion, when and if this show is ever brought back on the air, I hope that you catch it one day before it goes off the air for good.
#
# 0 - I used to watch this show when I was a little girl.
# 1 - Although I don't remember much about it, I must say that it was a pretty good show.
# 2 - Also, I don't think I've seen every episode.
# 3 - However, if you ask me, it was still a good show.
# 4 - I vaguely remember the theme song.
# 5 - Everyone was ideally cast, the costume design was great.
# 6 - The performances were top-grade, too.
# 7 - I just hope some network brings this series back one day so that I'll be able to see every episode.
# 8 - Before I wrap this up, I'd like to say that I'll always remember this show in my memory forever, even though I don't think I've seen every episode.
# 9 - Now, in conclusion, when and if this show is ever brought back on the air, I hope that you catch it one day before it goes off the air for good.
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 15
# Prueba 1, ok
# Prueba 2, ok
# 0.0 - 0.0
# SR = LO False
#
# Doc:
# How has this piece of crap stayed on TV this long? It's terrible. It makes me want to shoot someone. It's so fake that it is actually worse than a 1940s sci-fi movie. I'd rather have a stroke than watch this nonsense. I remember watching it when it first came out. I thought, hey this could be interesting, then I found out how absolutely, insanely, ridiculously stupid it really was. It was so bad that I actually took out my pocket knife and stuck my hand to the table.  Please people, stop watching this and all other reality shows, they're the trash that is jamming the networks and canceling quality programming that requires some thought to create.
#
# 0 - How has this piece of crap stayed on TV this long?
# 1 - It's terrible.
# 2 - It makes me want to shoot someone.
# 3 - It's so fake that it is actually worse than a 1940s sci-fi movie.
# 4 - I'd rather have a stroke than watch this nonsense.
# 5 - I remember watching it when it first came out.
# 6 - I thought, hey this could be interesting, then I found out how absolutely, insanely, ridiculously stupid it really was.
# 7 - It was so bad that I actually took out my pocket knife and stuck my hand to the table.
# 8 - Please people, stop watching this and all other reality shows, they're the trash that is jamming the networks and canceling quality programming that requires some thought to create.
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 16
# Prueba 1, ok
# Prueba 2, ok
# 0.0 - 0.0
# SR = LO False
#
# Doc:
# I was previously unaware that in the early 1990's Devry University (or was it ITT Tech?) added Film to its wonderful repertoire of technical degree programs. Well this movie must have been the product of the class valedictorian. My friend and I rented the original 1980 Boogeyman on my Netflix and this movie was on the flip side of the DVD. Do not waste your time with this movie. Awful awful awful.   The filmmaker adds 2 main character's, a woman and her therapist. The woman has been having dreams about the Boogeyman and his victim's from the first film. Over 50% of this film is stock from the original movie. The rest of the movie is the main character having the bad dreams while her therapist drones on a the narrator. These scenes are shot through a filter so thick the characters glow. They would make Angela Lansbury look 25 years old. So, to recap, awful. Don't watch this movie.
#
# 0 - I was previously unaware that in the early 1990's Devry University (or was it ITT Tech?)
# 1 - added Film to its wonderful repertoire of technical degree programs.
# 2 - Well this movie must have been the product of the class valedictorian.
# 3 - My friend and I rented the original 1980 Boogeyman on my Netflix and this movie was on the flip side of the DVD.
# 4 - Do not waste your time with this movie.
# 5 - Awful awful awful.
# 6 - The filmmaker adds 2 main character's, a woman and her therapist.
# 7 - The woman has been having dreams about the Boogeyman and his victim's from the first film.
# 8 - Over 50% of this film is stock from the original movie.
# 9 - The rest of the movie is the main character having the bad dreams while her therapist drones on a the narrator.
# 10 - These scenes are shot through a filter so thick the characters glow.
# 11 - They would make Angela Lansbury look 25 years old.
# 12 - So, to recap, awful.
# 13 - Don't watch this movie.
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 17
# Prueba 1, ok
# Prueba 2, ok
# 1.0 - 2.0
# SR = LO True
#
# Doc:
# Of life in (some) colleges. Of course there were artistic licenses taken, but some of what you saw in this film go on in some colleges.  I went to colleges in Southern California where the races pretty much hang around with their own. It's funny because these are schools that want racial unity, equality etc. and I can honestly say, that it's there. But the thing is when class lets out, or when they're just hanging out waiting for class, they (students) seem to just hang around with people of their own race or ethnicity. Is that bad? Not really. Everyone needs a feeling of belonging. But like the school paper of one of the schools I attended once wrote about that, "we should all try to hang around with students of other ethnicities and try to know them." Otherwise you're creating your own segregation.  Racism certainly existed in one of those schools I attended. One time someone put leaflets around campus talking about the glories of the Aryan Race and had the symbols of some of those racist organizations. Fortunately, nothing happened like the incident in the movie where the young Caucasian man went off and started shooting at a multiculturalism gathering.  I can only hope and pray that nothing like that ever will happen.  So is "Higher Learning" overly dramatic? Exaggerated? Maybe. Is it way "off mark?" It depends on where you went to or go to school. The race thing where the ethnicities just hang around with their own DOES happen. Minus the Hollywood exaggerations, the race thing hit pretty close to home for me.
#
# 0 - Of life in (some) colleges.
# 1 - Of course there were artistic licenses taken, but some of what you saw in this film go on in some colleges.
# 2 - I went to colleges in Southern California where the races pretty much hang around with their own.
# 3 - It's funny because these are schools that want racial unity, equality etc.
# 4 - and I can honestly say, that it's there.
# 5 - But the thing is when class lets out, or when they're just hanging out waiting for class, they (students) seem to just hang around with people of their own race or ethnicity.
# 6 - Is that bad?
# 7 - Not really.
# 8 - Everyone needs a feeling of belonging.
# 9 - But like the school paper of one of the schools I attended once wrote about that, "we should all try to hang around with students of other ethnicities and try to know them."
# 10 - Otherwise you're creating your own segregation.
# 11 - Racism certainly existed in one of those schools I attended.
# 12 - One time someone put leaflets around campus talking about the glories of the Aryan Race and had the symbols of some of those racist organizations.
# 13 - Fortunately, nothing happened like the incident in the movie where the young Caucasian man went off and started shooting at a multiculturalism gathering.
# 14 - I can only hope and pray that nothing like that ever will happen.
# 15 - So is "Higher Learning" overly dramatic?
# 16 - Exaggerated?
# 17 - Maybe.
# 18 - Is it way "off mark?"
# 19 - It depends on where you went to or go to school.
# 20 - The race thing where the ethnicities just hang around with their own DOES happen.
# 21 - Minus the Hollywood exaggerations, the race thing hit pretty close to home for me.
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 18
# Prueba 1, ok
# Prueba 2, ok
# 0.0 - 1.0
# SR = LO False
#
# Doc:
# Blood Surf AKA Krocodylus is a fair film that has an okay cast which includes Dax Miller, Taryn Reif, Kate Fischer, Duncan Regehr, Joel West, Matt Borlenghi, Maureen Larrazabal, Cris Vertido, Susan Africa, Archie Adamos, Rolando Santo Domingo, and Malecio Amayao. The acting by the actors is fairly good. The thrills are fairly good and some of it is surprising. The movie is filmed fairly good as well. Same thing goes for the music The film is fairly interesting and the movie does keeps you going until the end. This is a fairly thrilling film. If you the the cast in the film, Monsters, Giant Animal films, Horror, Thrillers, Mystery, and interesting films then I recommend you to see this film today!
#
# 0 - Blood Surf AKA Krocodylus is a fair film that has an okay cast which includes Dax Miller, Taryn Reif, Kate Fischer, Duncan Regehr, Joel West, Matt Borlenghi, Maureen Larrazabal, Cris Vertido, Susan Africa, Archie Adamos, Rolando Santo Domingo, and Malecio Amayao.
# 1 - The acting by the actors is fairly good.
# 2 - The thrills are fairly good and some of it is surprising.
# 3 - The movie is filmed fairly good as well.
# 4 - Same thing goes for the music The film is fairly interesting and the movie does keeps you going until the end.
# 5 - This is a fairly thrilling film.
# 6 - If you the the cast in the film, Monsters, Giant Animal films, Horror, Thrillers, Mystery, and interesting films then I recommend you to see this film today!
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 19
# Prueba 1, ok
# Prueba 2, ok
# 0.0 - 0.0
# SR = LO False
#
# Doc:
# ...
# 195
# Prueba 1, ok
# Prueba 2, ok
# 1.0 - 1.0
# SR = LO True
#
# Doc:
# This film is so old I never realized how young looking Ray Milland looked in 1936, I remember him playing in a great film, "Lost Weekend". Ray plays the role of Michael Stuart, who is a very rich banker. There are three girls in this picture who are not very happy about their father and mother separating and they find out their father is going to get married to a young blonde who is a gold digger only looking for a rich sugar daddy. They hire a man to pose as a very rich Count, his name is Count Ariszted, (Misha Auer) who is drunk all the time and is penniless and gives plenty of comic laughs throughout the picture. Deanna Durbin, (Penny Craig) surprised everyone when she was booked in a police station and told the chief of police that she was an opera star and then Penny starts singing with the most fantastic soprano voice I have every heard, the entire police department and convicts started applauding, which was a very entertaining and enjoyable scene from this film. This is Deanna Durbin's first film debut and she became an instant success over night and went on to become a great movie star with Universal Studios after leaving MGM.
#
# 0 - This film is so old I never realized how young looking Ray Milland looked in 1936, I remember him playing in a great film, "Lost Weekend".
# 1 - Ray plays the role of Michael Stuart, who is a very rich banker.
# 2 - There are three girls in this picture who are not very happy about their father and mother separating and they find out their father is going to get married to a young blonde who is a gold digger only looking for a rich sugar daddy.
# 3 - They hire a man to pose as a very rich Count, his name is Count Ariszted, (Misha Auer) who is drunk all the time and is penniless and gives plenty of comic laughs throughout the picture.
# 4 - Deanna Durbin, (Penny Craig) surprised everyone when she was booked in a police station and told the chief of police that she was an opera star and then Penny starts singing with the most fantastic soprano voice I have every heard, the entire police department and convicts started applauding, which was a very entertaining and enjoyable scene from this film.
# 5 - This is Deanna Durbin's first film debut and she became an instant success over night and went on to become a great movie star with Universal Studios after leaving MGM.
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 196
# Prueba 1, ok
# Prueba 2, ok
# 1.0 - 1.0
# SR = LO True
#
# Doc:
# I'm an admirer of Hal Hartley's films, especially 1997's "Henry Fool." "Fay Grim" is a sequel to that film, and has a similar style and sense of humor. The plot, however, is completely different. Fay Grim (played brilliantly by the iconic Parker Posey) tries to track down her missing husband's notebooks, and finds herself amid conspiracies and espionage. The supporting cast (most of the folks from the first film as well as Jeff Goldblum, Saffron Burrows, and a much-welcomed return from 90s indie-darling Elina Lowensohn) is excellent and the film has lots of surprises. The director claims this is part of a "Star Wars"-like trilogy, serving as the "Empire Strikes Back" of the series If this is true, I can't wait to see the third installment! I just hope I don't have to wait 10 more years for it.
#
# 0 - I'm an admirer of Hal Hartley's films, especially 1997's "Henry Fool."
# 1 - "Fay Grim" is a sequel to that film, and has a similar style and sense of humor.
# 2 - The plot, however, is completely different.
# 3 - Fay Grim (played brilliantly by the iconic Parker Posey) tries to track down her missing husband's notebooks, and finds herself amid conspiracies and espionage.
# 4 - The supporting cast (most of the folks from the first film as well as Jeff Goldblum, Saffron Burrows, and a much-welcomed return from 90s indie-darling Elina Lowensohn) is excellent and the film has lots of surprises.
# 5 - The director claims this is part of a "Star Wars"-like trilogy, serving as the "Empire Strikes Back" of the series If this is true, I can't wait to see the third installment!
# 6 - I just hope I don't have to wait 10 more years for it.
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 197
# Prueba 1, ok
# Prueba 2, ok
# 1.0 - 2.0
# SR = LO False
#
# Doc:
# Several years ago when I first watched "Grey Gardens" I remember laughing and finding it hilarious camp. Years later I still laugh out loud when I watch it, but after many viewings I've come to see the beauty in the strange, twisted relationship between the inseparable "Big" Edith Bouvier Beale and her daughter "Little" Edith Bouvier Beale.  Mother and daughter living together in their decaying 28 room East Hampton mansion add a whole new meaning to the term "Shabby Chic". With innumerable cats, raccoons and opossums as roommates this Aunt and Niece of Jackie O. allowed filmmakers Albert and David Maysles into their mansion to film them living life day to day. The result is a hilarious, beautiful, sad and moving account of true love and anarchy rule.  The relationship between Big and Little Edie is a testament to the unbreakable bonds of love. And their lives an example of drive, determination and free-will. This movie has more to recommend it than I can put down into words. It is a rare experience that you must see for yourself.
#
# 0 - Several years ago when I first watched "Grey Gardens" I remember laughing and finding it hilarious camp.
# 1 - Years later I still laugh out loud when I watch it, but after many viewings I've come to see the beauty in the strange, twisted relationship between the inseparable "Big" Edith Bouvier Beale and her daughter "Little" Edith Bouvier Beale.
# 2 - Mother and daughter living together in their decaying 28 room East Hampton mansion add a whole new meaning to the term "Shabby Chic".
# 3 - With innumerable cats, raccoons and opossums as roommates this Aunt and Niece of Jackie O. allowed filmmakers Albert and David Maysles into their mansion to film them living life day to day.
# 4 - The result is a hilarious, beautiful, sad and moving account of true love and anarchy rule.
# 5 - The relationship between Big and Little Edie is a testament to the unbreakable bonds of love.
# 6 - And their lives an example of drive, determination and free-will.
# 7 - This movie has more to recommend it than I can put down into words.
# 8 - It is a rare experience that you must see for yourself.
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 198
# Prueba 1, ok
# Prueba 2, ok
# 0.0 - 1.0
# SR = LO False
#
# Doc:
# Vulpine Massacre should have been this movies actual title. And the tag-line should have read "Guaranteed to make your kids CRY!" This is a nature drama telling the story of a family of wild foxes in a remote region. Starting with the meeting and pairing of two young foxes and the eventual birth of a large family and the trials of raising them. The only speaking is done in narrative by a tree that stands over the den, giving insight into the animals loves and lives... Lovely scenery and gorgeous filming of the animals. Sounds good huh? Well from there things go straight to hell and then start drilling towards the core...  *** Spoilers Below - Or they it may be a Warning!***  Almost first off we learn one of the foxes is born blind. But seems to get along well enough and there's a beautifully cheerful musical score to accompany him... And then he dies... Next we have one of the siblings adventures. And then he dies... One of the sisters gets her screen-time... and then she dies...And so it goes like some horrific slasher movie as one fox after another is killed off by nature, in traps, just up and vanish, and even by a bunch of snowmobiles! By the end of the movie almost all the foxes have been massacred. Though mercifully no deaths are shown on screen. (Least not in the version we saw.) Unlike say "Tarka the Otter" the deaths in this movie are almost all pointless and border on the sadistic in the way hopes are built up and then snuffed out. One or two losses would have been acceptable. It is a nature film after all. But not nearly the whole family.  Do not go to see this film deceived by the cheery box into thinking its safe for the kids. Watch it with some foreknowledge that things are *not* going to go well at all and that you or your kids may be left feeling very badly depending on how sensitive you or they are. You may enjoy it. Or you may not...
#
# 0 - Vulpine Massacre should have been this movies actual title.
# 1 - And the tag-line should have read "Guaranteed to make your kids CRY!"
# 2 - This is a nature drama telling the story of a family of wild foxes in a remote region.
# 3 - Starting with the meeting and pairing of two young foxes and the eventual birth of a large family and the trials of raising them.
# 4 - The only speaking is done in narrative by a tree that stands over the den, giving insight into the animals loves and lives... Lovely scenery and gorgeous filming of the animals.
# 5 - Sounds good huh?
# 6 - Well from there things go straight to hell and then start drilling towards the core...  *** Spoilers Below - Or they it may be a Warning!
# 7 - ***  Almost first off we learn one of the foxes is born blind.
# 8 - But seems to get along well enough and there's a beautifully cheerful musical score to accompany him... And then he dies... Next we have one of the siblings adventures.
# 9 - And then he dies... One of the sisters gets her screen-time... and then she dies...And so it goes like some horrific slasher movie as one fox after another is killed off by nature, in traps, just up and vanish, and even by a bunch of snowmobiles!
# 10 - By the end of the movie almost all the foxes have been massacred.
# 11 - Though mercifully no deaths are shown on screen.
# 12 - (Least not in the version we saw.)
# 13 - Unlike say "Tarka the Otter" the deaths in this movie are almost all pointless and border on the sadistic in the way hopes are built up and then snuffed out.
# 14 - One or two losses would have been acceptable.
# 15 - It is a nature film after all.
# 16 - But not nearly the whole family.
# 17 - Do not go to see this film deceived by the cheery box into thinking its safe for the kids.
# 18 - Watch it with some foreknowledge that things are *not* going to go well at all and that you or your kids may be left feeling very badly depending on how sensitive you or they are.
# 19 - You may enjoy it.
# 20 - Or you may not...
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--
# 199
# Prueba 1, ok
# Prueba 2, ok
# 0.0 - 0.0
# SR = LO False
#
# Doc:
# A film like Amazing Grace and Chuck is a perfect example of how the left in this country just doesn't get it. They never did. And liberalism continues to slip further and further into political oblivion.  This film deals with a little league baseball star who decides to stop playing ball as a protest to the existence of nuclear weapons. The boy is understandably ridiculed until a bevy of professional athletes, led by former NBA star Alex English, join his cause. Not just a few of them join the cause. By the time his movement reaches its zenith, entire leagues of professional and college sports have to cancel their seasons since nobody will play any more. Just to move this review along, I'm prepared to grant them this premise. Even though it would never happen in a million years, I'll just imagine it could, then go from there.  I don't quite remember how, but some type of agreement is reached, and the boy decides to go back to the game he loves in an incredibly sappy and ridiculous scene.  Before criticizing the message of this film, let me just say that this film is poorly written, acted and directed. Even if one does agree with the boy's stance, it would be impossible to overcome how badly the film was constructed. And that's a shame since there are plenty of good actors that go to waste. (Peck, Curtis, Petersen). Alex English does as well as he could have with his character however, and I wish he would try to act in more films. Alas, it's likely much easier to find work in the coaching world of the NBA. One wishes Mr. English would teach more of these thuggish NBA types of today how to shoot the rock a little better. Alex certainly knew how to put the ball through the hoop.  As far as the film's message in concerned, it's just wrong-headed. Plain and simple. All of those nuclear warheads tucked away in those missile silos out west PREVENTED WAR!!!!! It would be one thing for this boy and his flock to protest an actual war or the USE of nuclear weapons. These weapons were in fact never used, and that was the genius behind their existence. Neither side during the cold war was crazy enough to fire a single missile. Without these weapons, who knows what might have happened between the USA and USSR.  The makers of this film obviously intended for kids in America to take up their cause and follow in Chuck's footsteps. Kids in America however are more intelligent than the left wing kooks who created this dreck.   The film is worth only 2 of 10 stars.  If you want to see a great film about the dangers of nuclear war, stick with Dr. Strangelove, instead.  Mr. Newell, you are no Frank Capra!
#
# 0 - A film like Amazing Grace and Chuck is a perfect example of how the left in this country just doesn't get it.
# 1 - They never did.
# 2 - And liberalism continues to slip further and further into political oblivion.
# 3 - This film deals with a little league baseball star who decides to stop playing ball as a protest to the existence of nuclear weapons.
# 4 - The boy is understandably ridiculed until a bevy of professional athletes, led by former NBA star Alex English, join his cause.
# 5 - Not just a few of them join the cause.
# 6 - By the time his movement reaches its zenith, entire leagues of professional and college sports have to cancel their seasons since nobody will play any more.
# 7 - Just to move this review along, I'm prepared to grant them this premise.
# 8 - Even though it would never happen in a million years, I'll just imagine it could, then go from there.
# 9 - I don't quite remember how, but some type of agreement is reached, and the boy decides to go back to the game he loves in an incredibly sappy and ridiculous scene.
# 10 - Before criticizing the message of this film, let me just say that this film is poorly written, acted and directed.
# 11 - Even if one does agree with the boy's stance, it would be impossible to overcome how badly the film was constructed.
# 12 - And that's a shame since there are plenty of good actors that go to waste.
# 13 - (Peck, Curtis, Petersen).
# 14 - Alex English does as well as he could have with his character however, and I wish he would try to act in more films.
# 15 - Alas, it's likely much easier to find work in the coaching world of the NBA.
# 16 - One wishes Mr. English would teach more of these thuggish NBA types of today how to shoot the rock a little better.
# 17 - Alex certainly knew how to put the ball through the hoop.
# 18 - As far as the film's message in concerned, it's just wrong-headed.
# 19 - Plain and simple.
# 20 - All of those nuclear warheads tucked away in those missile silos out west PREVENTED WAR!!!!!
# 21 - It would be one thing for this boy and his flock to protest an actual war or the USE of nuclear weapons.
# 22 - These weapons were in fact never used, and that was the genius behind their existence.
# 23 - Neither side during the cold war was crazy enough to fire a single missile.
# 24 - Without these weapons, who knows what might have happened between the USA and USSR.
# 25 - The makers of this film obviously intended for kids in America to take up their cause and follow in Chuck's footsteps.
# 26 - Kids in America however are more intelligent than the left wing kooks who created this dreck.
# 27 - The film is worth only 2 of 10 stars.
# 28 - If you want to see a great film about the dangers of nuclear war, stick with Dr. Strangelove, instead.
# 29 - Mr. Newell, you are no Frank Capra!
# *--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--*--

# %%
match_f1 = [x[0] for x in matches]
match_lo = [x[1] for x in matches]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-813fa8d095dc> in <module>()
# ----> 1 match_f1 = [x[0] for x in matches]
#       2 match_lo = [x[1] for x in matches]
#
# NameError: name 'matches' is not defined

# %%
print "match f1:", 1. * np.sum(match_f1)/len(match_f1)
print "match longest:", 1. * np.sum(match_lo)/len(match_f1)
# Out:
# match f1: 0.11
# match longest: 0.215

# %%
c = Counter(sr_picks)
print c.most_common(5)
# Out:
# [(1, 32), (4, 28), (2, 24), (0, 22), (3, 16)]

# %%
for pos in sr_picks:
    print pos
# Out:
# 0
# 2
# 6
# 20
# 1
# 4
# 8
# 4
# 1
# 0
# 8
# 4
# 3
# 2
# 1
# 1
# 4
# 9
# 4
# 4
# 9
# 10
# 1
# 8
# 4
# 8
# 5
# 1
# 15
# 4
# 2
# 6
# 8
# 6
# 1
# 6
# 1
# 2
# 3
# 6
# 0
# 4
# 2
# 6
# 1
# 3
# 0
# 4
# 8
# 12
# 1
# 7
# 9
# 4
# 1
# 1
# 4
# 8
# 22
# 2
# 0
# 0
# 2
# 2
# 4
# 0
# 4
# 2
# 3
# 4
# 3
# 3
# 0
# 1
# 0
# 9
# 2
# 2
# 9
# 1
# 10
# 1
# 1
# 2
# 6
# 9
# 4
# 10
# 28
# 7
# 2
# 11
# 3
# 17
# 2
# 0
# 1
# 5
# 2
# 3
# 15
# 16
# 4
# 29
# 0
# 12
# 4
# 8
# 1
# 1
# 0
# 19
# 2
# 0
# 6
# 9
# 3
# 13
# 11
# 12
# 32
# 7
# 26
# 6
# 5
# 3
# 2
# 2
# 0
# 0
# 3
# 5
# 1
# 1
# 7
# 4
# 4
# 10
# 21
# 12
# 5
# 7
# 9
# 4
# 1
# 1
# 2
# 15
# 43
# 0
# 0
# 78
# 1
# 7
# 9
# 12
# 2
# 2
# 8
# 0
# 1
# 13
# 6
# 0
# 5
# 1
# 14
# 3
# 10
# 4
# 4
# 3
# 1
# 7
# 5
# 4
# 3
# 0
# 0
# 1
# 8
# 8
# 4
# 7
# 1
# 7
# 1
# 3
# 1
# 2
# 2
# 4
# 3
# 1
# 16
# 4
# 4
# 2
# 18
# 0
